# %%
# https://github.com/open-mmlab/mmdetection/blob/master/demo/MMDet_Tutorial.ipynb 에서 발췌

# %%
# mmcv를 위해서 mmcv-full을 먼저 설치해야 함. 
# !pip install mmcv-full
# mmdetection 설치 
# !git clone https://github.com/open-mmlab/mmdetection.git
# !cd mmdetection; python setup.py install
# Out:
# Collecting mmcv-full
#   Downloading mmcv-full-1.3.12.tar.gz (309 kB)
#      |████████████████████████████████| 309 kB 7.5 MB/s
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (21.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (7.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (3.13)
# Collecting yapf
#   Downloading yapf-0.31.0-py2.py3-none-any.whl (185 kB)
#      |████████████████████████████████| 185 kB 80.5 MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mmcv-full) (2.4.7)
# Building wheels for collected packages: mmcv-full
#   Building wheel for mmcv-full (setup.py) ... done
#   Created wheel for mmcv-full: filename=mmcv_full-1.3.12-cp37-cp37m-linux_x86_64.whl size=29349838 sha256=80e9881155c6a9c34d534d1e1eb21bc9a26a85dfb733bdb0b8a79c55ace51d0a
#   Stored in directory: /root/.cache/pip/wheels/3a/a4/e1/61968a1aca1a84435171a4162f9a80872951c7b7ff0662ac87
# Successfully built mmcv-full
# Installing collected packages: yapf, addict, mmcv-full
# Successfully installed addict-2.4.0 mmcv-full-1.3.12 yapf-0.31.0
# Cloning into 'mmdetection'...
# remote: Enumerating objects: 20539, done.
# remote: Counting objects: 100% (1213/1213), done.
# remote: Compressing objects: 100% (899/899), done.
# remote: Total 20539 (delta 503), reused 752 (delta 313), pack-reused 19326
# Receiving objects: 100% (20539/20539), 25.04 MiB | 30.81 MiB/s, done.
# Resolving deltas: 100% (13977/13977), done.
# running install
# running bdist_egg
# running egg_info
# creating mmdet.egg-info
# writing mmdet.egg-info/PKG-INFO
# writing dependency_links to mmdet.egg-info/dependency_links.txt
# writing requirements to mmdet.egg-info/requires.txt
# writing top-level names to mmdet.egg-info/top_level.txt
# writing manifest file 'mmdet.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'mmdet/VERSION'
# warning: no files found matching 'mmdet/.mim/model-index.yml'
# warning: no files found matching 'mmdet/.mim/demo/*/*'
# warning: no files found matching '*.py' under directory 'mmdet/.mim/configs'
# warning: no files found matching '*.yml' under directory 'mmdet/.mim/configs'
# warning: no files found matching '*.sh' under directory 'mmdet/.mim/tools'
# warning: no files found matching '*.py' under directory 'mmdet/.mim/tools'
# adding license file 'LICENSE'
# writing manifest file 'mmdet.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/mmdet
# copying mmdet/version.py -> build/lib/mmdet
# copying mmdet/__init__.py -> build/lib/mmdet
# creating build/lib/mmdet/utils
# copying mmdet/utils/logger.py -> build/lib/mmdet/utils
# copying mmdet/utils/contextmanagers.py -> build/lib/mmdet/utils
# copying mmdet/utils/profiling.py -> build/lib/mmdet/utils
# copying mmdet/utils/__init__.py -> build/lib/mmdet/utils
# copying mmdet/utils/collect_env.py -> build/lib/mmdet/utils
# copying mmdet/utils/util_mixins.py -> build/lib/mmdet/utils
# copying mmdet/utils/util_random.py -> build/lib/mmdet/utils
# creating build/lib/mmdet/apis
# copying mmdet/apis/inference.py -> build/lib/mmdet/apis
# copying mmdet/apis/test.py -> build/lib/mmdet/apis
# copying mmdet/apis/train.py -> build/lib/mmdet/apis
# copying mmdet/apis/__init__.py -> build/lib/mmdet/apis
# creating build/lib/mmdet/models
# copying mmdet/models/builder.py -> build/lib/mmdet/models
# copying mmdet/models/__init__.py -> build/lib/mmdet/models
# creating build/lib/mmdet/datasets
# copying mmdet/datasets/builder.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/utils.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/deepfashion.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/dataset_wrappers.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/coco_panoptic.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/custom.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/wider_face.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/xml_style.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/cityscapes.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/coco.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/__init__.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/voc.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/lvis.py -> build/lib/mmdet/datasets
# creating build/lib/mmdet/core
# copying mmdet/core/__init__.py -> build/lib/mmdet/core
# creating build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/cascade_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/deformable_detr.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/cornernet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fcos.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/atss.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/paa.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fast_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/reppoints_detector.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/htc.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/point_rend.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/trident_faster_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/detr.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/retinanet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/two_stage.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolof.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/panoptic_fpn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/panoptic_two_stage_segmentor.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/nasfcos.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/gfl.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/mask_scoring_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/autoassign.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolo.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolox.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/__init__.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/vfnet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/mask_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/scnet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/rpn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/kd_one_stage.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/sparse_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolact.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fovea.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/single_stage.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/grid_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/base.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/faster_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/centernet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fsaf.py -> build/lib/mmdet/models/detectors
# creating build/lib/mmdet/models/losses
# copying mmdet/models/losses/mse_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/seesaw_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/utils.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/balanced_l1_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/iou_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/smooth_l1_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/cross_entropy_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/__init__.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/gfocal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/focal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/ghm_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/ae_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/gaussian_focal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/pisa_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/kd_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/accuracy.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/varifocal_loss.py -> build/lib/mmdet/models/losses
# creating build/lib/mmdet/models/necks
# copying mmdet/models/necks/fpg.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/rfp.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/ssd_neck.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/hrfpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/channel_mapper.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/fpn_carafe.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/bfp.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/ct_resnet_neck.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/nas_fpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/__init__.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/yolox_pafpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/nasfcos_fpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/fpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/yolo_neck.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/dilated_encoder.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/pafpn.py -> build/lib/mmdet/models/necks
# creating build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/csp_darknet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/detectors_resnext.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/swin.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/ssd_vgg.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/trident_resnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/detectors_resnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/resnext.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/hrnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/darknet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/__init__.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/regnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/mobilenet_v2.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/hourglass.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/resnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/resnest.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/res2net.py -> build/lib/mmdet/models/backbones
# creating build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/mask_scoring_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/sparse_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/dynamic_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/pisa_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/htc_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/scnet_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/grid_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/trident_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/test_mixins.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/base_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/__init__.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/standard_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/double_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/cascade_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/point_rend_roi_head.py -> build/lib/mmdet/models/roi_heads
# creating build/lib/mmdet/models/utils
# copying mmdet/models/utils/misc.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/builder.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/se_layer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/conv_upsample.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/csp_layer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/gaussian_target.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/__init__.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/transformer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/normed_predictor.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/res_layer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/positional_encoding.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/inverted_residual.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/ckpt_convert.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/make_divisible.py -> build/lib/mmdet/models/utils
# creating build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/pisa_ssd_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/detr_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/centripetal_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/pisa_retinanet_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ssd_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ga_rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/paa_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/gfl_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/fovea_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolo_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/guided_anchor_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/centernet_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/dense_test_mixins.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/nasfcos_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/free_anchor_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/cascade_rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/vfnet_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/atss_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/sabl_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/deformable_detr_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ld_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/fsaf_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/embedding_rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolact_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/__init__.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/corner_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/autoassign_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolox_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/base_dense_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/anchor_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/retina_sepbn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/reppoints_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolof_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/fcos_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ga_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/anchor_free_head.py -> build/lib/mmdet/models/dense_heads
# creating build/lib/mmdet/models/seg_heads
# copying mmdet/models/seg_heads/base_semantic_head.py -> build/lib/mmdet/models/seg_heads
# copying mmdet/models/seg_heads/__init__.py -> build/lib/mmdet/models/seg_heads
# copying mmdet/models/seg_heads/panoptic_fpn_head.py -> build/lib/mmdet/models/seg_heads
# creating build/lib/mmdet/models/plugins
# copying mmdet/models/plugins/dropblock.py -> build/lib/mmdet/models/plugins
# copying mmdet/models/plugins/__init__.py -> build/lib/mmdet/models/plugins
# creating build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/scnet_bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/convfc_bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/dii_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/__init__.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/sabl_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/double_bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# creating build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/grid_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/global_context_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/coarse_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/htc_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/scnet_semantic_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/feature_relay_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/mask_point_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/fused_semantic_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/maskiou_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/__init__.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/scnet_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/fcn_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# creating build/lib/mmdet/models/roi_heads/shared_heads
# copying mmdet/models/roi_heads/shared_heads/__init__.py -> build/lib/mmdet/models/roi_heads/shared_heads
# copying mmdet/models/roi_heads/shared_heads/res_layer.py -> build/lib/mmdet/models/roi_heads/shared_heads
# creating build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/base_roi_extractor.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/__init__.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/generic_roi_extractor.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/single_level_roi_extractor.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# creating build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/heuristic_fusion_head.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/__init__.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/base_panoptic_fusion_head.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# creating build/lib/mmdet/datasets/api_wrappers
# copying mmdet/datasets/api_wrappers/coco_api.py -> build/lib/mmdet/datasets/api_wrappers
# copying mmdet/datasets/api_wrappers/__init__.py -> build/lib/mmdet/datasets/api_wrappers
# creating build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/group_sampler.py -> build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/__init__.py -> build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/distributed_sampler.py -> build/lib/mmdet/datasets/samplers
# creating build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/auto_augment.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/test_time_aug.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/compose.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/transforms.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/__init__.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/instaboost.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/formating.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/loading.py -> build/lib/mmdet/datasets/pipelines
# creating build/lib/mmdet/core/visualization
# copying mmdet/core/visualization/image.py -> build/lib/mmdet/core/visualization
# copying mmdet/core/visualization/__init__.py -> build/lib/mmdet/core/visualization
# creating build/lib/mmdet/core/mask
# copying mmdet/core/mask/utils.py -> build/lib/mmdet/core/mask
# copying mmdet/core/mask/mask_target.py -> build/lib/mmdet/core/mask
# copying mmdet/core/mask/__init__.py -> build/lib/mmdet/core/mask
# copying mmdet/core/mask/structures.py -> build/lib/mmdet/core/mask
# creating build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/builder.py -> build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/demodata.py -> build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/transforms.py -> build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/__init__.py -> build/lib/mmdet/core/bbox
# creating build/lib/mmdet/core/utils
# copying mmdet/core/utils/misc.py -> build/lib/mmdet/core/utils
# copying mmdet/core/utils/dist_utils.py -> build/lib/mmdet/core/utils
# copying mmdet/core/utils/__init__.py -> build/lib/mmdet/core/utils
# creating build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/builder.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/utils.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/point_generator.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/anchor_generator.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/__init__.py -> build/lib/mmdet/core/anchor
# creating build/lib/mmdet/core/hook
# copying mmdet/core/hook/checkloss_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/sync_norm_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/sync_random_size_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/__init__.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/ema.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/yolox_lrupdater_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/yolox_mode_switch_hook.py -> build/lib/mmdet/core/hook
# creating build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/__init__.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/mean_ap.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/recall.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/eval_hooks.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/bbox_overlaps.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/class_names.py -> build/lib/mmdet/core/evaluation
# creating build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/bbox_nms.py -> build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/merge_augs.py -> build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/__init__.py -> build/lib/mmdet/core/post_processing
# creating build/lib/mmdet/core/export
# copying mmdet/core/export/pytorch2onnx.py -> build/lib/mmdet/core/export
# copying mmdet/core/export/__init__.py -> build/lib/mmdet/core/export
# copying mmdet/core/export/model_wrappers.py -> build/lib/mmdet/core/export
# copying mmdet/core/export/onnx_helper.py -> build/lib/mmdet/core/export
# creating build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/point_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/base_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/sim_ota_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/atss_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/grid_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/max_iou_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/hungarian_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/uniform_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/__init__.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/approx_max_iou_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/region_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/center_region_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/assign_result.py -> build/lib/mmdet/core/bbox/assigners
# creating build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/yolo_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/pseudo_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/legacy_delta_xywh_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/bucketing_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/tblr_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/delta_xywh_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/__init__.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/base_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# creating build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/ohem_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/base_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/pseudo_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/__init__.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/combined_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/sampling_result.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/score_hlr_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/instance_balanced_pos_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/random_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/iou_balanced_neg_sampler.py -> build/lib/mmdet/core/bbox/samplers
# creating build/lib/mmdet/core/bbox/match_costs
# copying mmdet/core/bbox/match_costs/builder.py -> build/lib/mmdet/core/bbox/match_costs
# copying mmdet/core/bbox/match_costs/match_cost.py -> build/lib/mmdet/core/bbox/match_costs
# copying mmdet/core/bbox/match_costs/__init__.py -> build/lib/mmdet/core/bbox/match_costs
# creating build/lib/mmdet/core/bbox/iou_calculators
# copying mmdet/core/bbox/iou_calculators/builder.py -> build/lib/mmdet/core/bbox/iou_calculators
# copying mmdet/core/bbox/iou_calculators/__init__.py -> build/lib/mmdet/core/bbox/iou_calculators
# copying mmdet/core/bbox/iou_calculators/iou2d_calculator.py -> build/lib/mmdet/core/bbox/iou_calculators
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/mmdet
# copying build/lib/mmdet/version.py -> build/bdist.linux-x86_64/egg/mmdet
# creating build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/logger.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/contextmanagers.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/profiling.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/collect_env.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/util_mixins.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/util_random.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# creating build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/inference.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/test.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/train.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# creating build/bdist.linux-x86_64/egg/mmdet/models
# creating build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/cascade_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/deformable_detr.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/cornernet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/fcos.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/atss.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/paa.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/fast_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/reppoints_detector.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/htc.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/point_rend.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/trident_faster_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/detr.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/retinanet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/two_stage.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/yolof.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/panoptic_fpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/panoptic_two_stage_segmentor.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/nasfcos.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/gfl.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/mask_scoring_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/autoassign.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/yolo.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/yolox.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/vfnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/mask_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/scnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/rpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/kd_one_stage.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/sparse_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/yolact.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/fovea.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/single_stage.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/grid_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/base.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/faster_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/centernet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/fsaf.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# creating build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/mse_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/seesaw_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/utils.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/balanced_l1_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/iou_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/smooth_l1_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/cross_entropy_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/gfocal_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/focal_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/ghm_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/ae_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/gaussian_focal_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/pisa_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/kd_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/accuracy.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/varifocal_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/builder.py -> build/bdist.linux-x86_64/egg/mmdet/models
# creating build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/fpg.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/rfp.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/ssd_neck.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/hrfpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/channel_mapper.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/fpn_carafe.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/bfp.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/ct_resnet_neck.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/nas_fpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/yolox_pafpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/nasfcos_fpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/fpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/yolo_neck.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/dilated_encoder.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/pafpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# creating build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/csp_darknet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/detectors_resnext.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/swin.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/ssd_vgg.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/trident_resnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/detectors_resnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/resnext.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/hrnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/darknet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/regnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/mobilenet_v2.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/hourglass.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/resnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/resnest.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/res2net.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/mask_scoring_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/sparse_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/dynamic_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/pisa_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/htc_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/scnet_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/scnet_bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/convfc_bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/dii_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/sabl_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/double_bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/grid_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/grid_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/global_context_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/coarse_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/htc_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/scnet_semantic_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/feature_relay_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/mask_point_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/fused_semantic_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/maskiou_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/scnet_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/trident_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/test_mixins.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/base_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/standard_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/double_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/cascade_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/shared_heads
# copying build/lib/mmdet/models/roi_heads/shared_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/shared_heads
# copying build/lib/mmdet/models/roi_heads/shared_heads/res_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/shared_heads
# copying build/lib/mmdet/models/roi_heads/point_rend_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/base_roi_extractor.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/generic_roi_extractor.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/single_level_roi_extractor.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# creating build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/misc.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/builder.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/se_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/conv_upsample.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/csp_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/gaussian_target.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/transformer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/normed_predictor.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/res_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/positional_encoding.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/inverted_residual.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/ckpt_convert.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/make_divisible.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models
# creating build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/pisa_ssd_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/detr_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/rpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/centripetal_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/pisa_retinanet_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ssd_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# ...
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads/base_panoptic_fusion_head.py to base_panoptic_fusion_head.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fpn_head.py to panoptic_fpn_head.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/plugins/dropblock.py to dropblock.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/plugins/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers/coco_api.py to coco_api.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/builder.py to builder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/utils.py to utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/deepfashion.py to deepfashion.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/dataset_wrappers.py to dataset_wrappers.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/coco_panoptic.py to coco_panoptic.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/custom.py to custom.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/samplers/group_sampler.py to group_sampler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/samplers/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/samplers/distributed_sampler.py to distributed_sampler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/wider_face.py to wider_face.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/xml_style.py to xml_style.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/cityscapes.py to cityscapes.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/coco.py to coco.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/voc.py to voc.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/auto_augment.py to auto_augment.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/test_time_aug.py to test_time_aug.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/compose.py to compose.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/transforms.py to transforms.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/instaboost.py to instaboost.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/formating.py to formating.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/loading.py to loading.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/lvis.py to lvis.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/image.py to image.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/utils.py to utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/mask_target.py to mask_target.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/structures.py to structures.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/builder.py to builder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/demodata.py to demodata.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/point_assigner.py to point_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/base_assigner.py to base_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/sim_ota_assigner.py to sim_ota_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/atss_assigner.py to atss_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/grid_assigner.py to grid_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/max_iou_assigner.py to max_iou_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/hungarian_assigner.py to hungarian_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/uniform_assigner.py to uniform_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/approx_max_iou_assigner.py to approx_max_iou_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/region_assigner.py to region_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/center_region_assigner.py to center_region_assigner.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/assign_result.py to assign_result.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/yolo_bbox_coder.py to yolo_bbox_coder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/pseudo_bbox_coder.py to pseudo_bbox_coder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/legacy_delta_xywh_bbox_coder.py to legacy_delta_xywh_bbox_coder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/bucketing_bbox_coder.py to bucketing_bbox_coder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/tblr_bbox_coder.py to tblr_bbox_coder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/delta_xywh_bbox_coder.py to delta_xywh_bbox_coder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/base_bbox_coder.py to base_bbox_coder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/ohem_sampler.py to ohem_sampler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/base_sampler.py to base_sampler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/pseudo_sampler.py to pseudo_sampler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/combined_sampler.py to combined_sampler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/sampling_result.py to sampling_result.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/score_hlr_sampler.py to score_hlr_sampler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/instance_balanced_pos_sampler.py to instance_balanced_pos_sampler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/random_sampler.py to random_sampler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/iou_balanced_neg_sampler.py to iou_balanced_neg_sampler.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/builder.py to builder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/match_cost.py to match_cost.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/transforms.py to transforms.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/builder.py to builder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/iou2d_calculator.py to iou2d_calculator.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/misc.py to misc.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/dist_utils.py to dist_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/builder.py to builder.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/utils.py to utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/point_generator.py to point_generator.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/anchor_generator.py to anchor_generator.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/checkloss_hook.py to checkloss_hook.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/sync_norm_hook.py to sync_norm_hook.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/sync_random_size_hook.py to sync_random_size_hook.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/ema.py to ema.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/yolox_lrupdater_hook.py to yolox_lrupdater_hook.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/yolox_mode_switch_hook.py to yolox_mode_switch_hook.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/mean_ap.py to mean_ap.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/recall.py to recall.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/eval_hooks.py to eval_hooks.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/bbox_overlaps.py to bbox_overlaps.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/class_names.py to class_names.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/bbox_nms.py to bbox_nms.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/merge_augs.py to merge_augs.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/pytorch2onnx.py to pytorch2onnx.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/model_wrappers.py to model_wrappers.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/onnx_helper.py to onnx_helper.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/mmdet-2.16.0-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mmdet-2.16.0-py3.7.egg
# creating /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg
# Extracting mmdet-2.16.0-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding mmdet 2.16.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg
# Processing dependencies for mmdet==2.16.0
# Searching for terminaltables
# Reading https://pypi.org/simple/terminaltables/
# Downloading https://files.pythonhosted.org/packages/9b/c4/4a21174f32f8a7e1104798c445dacdc1d4df86f2f26722767034e4de4bff/terminaltables-3.1.0.tar.gz#sha256=f3eb0eb92e3833972ac36796293ca0906e998dc3be91fbe1f8615b331b853b81
# Best match: terminaltables 3.1.0
# Processing terminaltables-3.1.0.tar.gz
# Writing /tmp/easy_install-sm003fuu/terminaltables-3.1.0/setup.cfg
# Running terminaltables-3.1.0/setup.py -q bdist_egg --dist-dir /tmp/easy_install-sm003fuu/terminaltables-3.1.0/egg-dist-tmp-l99uc67r
# Moving terminaltables-3.1.0-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding terminaltables 3.1.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/terminaltables-3.1.0-py3.7.egg
# Searching for pycocotools==2.0.2
# Best match: pycocotools 2.0.2
# Adding pycocotools 2.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for matplotlib==3.2.2
# Best match: matplotlib 3.2.2
# Adding matplotlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for setuptools==57.4.0
# Best match: setuptools 57.4.0
# Adding setuptools 57.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Cython==0.29.24
# Best match: Cython 0.29.24
# Adding Cython 0.29.24 to easy-install.pth file
# Installing cygdb script to /usr/local/bin
# Installing cython script to /usr/local/bin
# Installing cythonize script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for kiwisolver==1.3.1
# Best match: kiwisolver 1.3.1
# Adding kiwisolver 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pyparsing==2.4.7
# Best match: pyparsing 2.4.7
# Adding pyparsing 2.4.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for cycler==0.10.0
# Best match: cycler 0.10.0
# Adding cycler 0.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for mmdet==2.16.0

# %%
# 아래를 수행하기 전에 kernel을 restart 해야 함. 
from mmdet.apis import init_detector, inference_detector
import mmcv

# %% [markdown]
# ## KITTI Dataset 다운로드
#
# - 작은 용량의 KITTI Dataset을 다운로드하고 /content 밑에 압축 해제

# %%
# !wget https://download.openmmlab.com/mmdetection/data/kitti_tiny.zip
# !unzip kitti_tiny.zip > /dev/null
# Out:
# --2021-09-02 13:46:25--  https://download.openmmlab.com/mmdetection/data/kitti_tiny.zip
# Resolving download.openmmlab.com (download.openmmlab.com)... 47.88.36.78
# Connecting to download.openmmlab.com (download.openmmlab.com)|47.88.36.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6918271 (6.6M) [application/zip]
# Saving to: ‘kitti_tiny.zip’
#
# kitti_tiny.zip      100%[===================>]   6.60M  5.90MB/s    in 1.1s
#
# 2021-09-02 13:46:27 (5.90 MB/s) - ‘kitti_tiny.zip’ saved [6918271/6918271]

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.cvtColor(cv2.imread('/content/kitti_tiny/training/image_2/000068.jpeg'), cv2.COLOR_BGR2RGB)
plt.figure(figsize=(15, 10))
plt.imshow(img)

# %% [markdown]
# ## KITTI DATA FORMAT 확인
#
# - 첫번째 컬럼은 해당 오브젝트의 클래스 명.
#
# - 5번째~8번째가 BOUNDING BOX 정보임. 좌상단(xmin, ymin), 우하단(xmax, ymax) 좌표 임.

# %%
# !cat /content/kitti_tiny/training/label_2/000068.txt
# Out:
# Car 0.25 0 1.94 69.26 200.28 435.08 374.00 1.46 1.62 4.04 -3.00 1.79 6.98 1.55
# Car 0.80 1 2.26 0.00 209.20 198.59 374.00 1.46 1.58 3.72 -5.44 1.85 6.22 1.56
# Cyclist 0.97 0 2.34 1210.28 199.77 1241.00 374.00 1.55 0.57 1.73 4.04 1.69 3.57 -3.14
# Car 0.00 2 1.68 478.18 187.68 549.54 249.43 1.57 1.60 3.99 -2.73 2.03 20.96 1.55
# Car 0.00 1 1.66 530.03 187.79 573.10 226.09 1.52 1.54 3.68 -2.53 2.20 31.50 1.58
# Van 0.00 1 1.63 547.61 171.12 584.05 212.41 2.47 1.98 5.81 -2.79 2.41 46.44 1.57
# Car 0.00 1 -0.16 667.74 182.35 790.82 230.38 1.62 1.65 4.14 4.19 1.99 25.95 0.00
# Car 0.00 2 -0.11 657.37 184.48 763.34 221.64 1.55 1.66 4.47 4.35 2.10 32.00 0.02
# Car 0.00 1 -0.01 637.45 180.34 714.44 212.34 1.69 1.76 4.12 3.59 2.12 39.79 0.08
# Van 0.00 1 1.61 572.52 175.02 596.26 199.95 2.13 1.91 6.40 -2.28 2.36 65.43 1.57
# Van 0.00 1 1.77 380.78 167.69 523.29 288.56 1.95 1.75 4.63 -2.89 1.90 14.05 1.57
# Cyclist 0.00 1 1.09 958.95 167.55 1036.88 254.43 1.68 0.53 1.96 7.95 1.59 14.95 1.57

# %% [markdown]
# ### KITTI annotation 파일들의 리스트들을 가지는 파일 확인

# %%
# !cat /content/kitti_tiny/train.txt
# Out:
# 000000
# 000001
# 000002
# 000003
# 000004
# 000005
# 000006
# 000007
# 000008
# 000009
# 000010
# 000011
# 000012
# 000013
# 000014
# 000015
# 000016
# 000017
# 000018
# 000019
# 000020
# 000021
# 000022
# 000023
# 000024
# 000025
# 000026
# 000027
# 000028
# 000029
# 000030
# 000031
# 000032
# 000033
# 000034
# 000035
# 000036
# 000037
# 000038
# 000039
# 000040
# 000041
# 000042
# 000043
# 000044
# 000045
# 000046
# 000047
# 000048
# 000049

# %% [markdown]
# <b> mmdetection의 중립 annotation 포맷 변환. 해당 포맷은 텍스트로 변환하지 않음. 바로 메모리 상의 list로 생성됨</b>
#
# - filename, width, height, ann을 Key로 가지는 Dictionary를 이미지 개수대로 가지는 list 생성.
#
#   - filename: 이미지 파일명(디렉토리는 포함하지 않음)
#   - width: 이미지 너비
#   - height: 이미지 높이
#   - ann: bbounding box와 label에 대한 정보를 가지는 Dictionary
#     - bboxes: 하나의 이미지에 있는 여러 Object 들의 numpy array. 4개의 좌표값(좌상단, 우하단)을 가지고, 해당 이미지에 n개의 Object들이 있을 경우 array의 shape는 (n, 4)
#     - labels: 하나의 이미지에 있는 여러 Object들의 numpy array. shape는 (n, )
#     - bboxes_ignore: 학습에 사용되지 않고 무시하는 bboxes. 무시하는 bboxes의 개수가 k개이면 shape는 (k, 4)
#     - labels_ignore: 학습에 사용되지 않고 무시하는 labels. 무시하는 bboxes의 개수가 k개이면 shape는 (k,)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Kitti Dataset을 중립 데이터형태로 변환하여 메모리 로드

# %%
# 원본 kitti Dataset는 10개의 Class로 되어 있음. 'Car Van Truck Pedestrian Person_sitting Cyclist Tram Misc DontCare'
CLASSES = ('Car', 'Truck', 'Pedestrian', 'Cyclist')
cat2label = {k:i for i, k in enumerate(CLASSES)}
print(cat2label)
cat2label['Car']
# Out:
# {'Car': 0, 'Truck': 1, 'Pedestrian': 2, 'Cyclist': 3}
# 0

# %%
image_list = mmcv.list_from_file('/content/kitti_tiny/train.txt')

# %%
lines = mmcv.list_from_file('/content/kitti_tiny/training/label_2/000064.txt')
#print(lines)
content = [line.strip().split(' ') for line in lines]
bbox_names = [x[0] for x in content]
#print(bbox)
bboxes = [ [float(info) for info in x[4:8]] for x in content]
print(bboxes)
# Out:
# [[657.65, 179.93, 709.86, 219.92], [731.51, 180.39, 882.28, 275.8], [715.18, 175.63, 762.77, 203.9], [816.58, 59.74, 1112.51, 266.07], [626.78, 174.27, 647.77, 192.18], [546.19, 168.97, 554.01, 177.09]]

# %%
import copy
import os.path as osp
import cv2

import mmcv
import numpy as np

from mmdet.datasets.builder import DATASETS
from mmdet.datasets.custom import CustomDataset

# 반드시 아래 Decorator 설정 할것.@DATASETS.register_module() 설정 시 force=True를 입력하지 않으면 Dataset 재등록 불가. 
@DATASETS.register_module(force=True)
class KittyTinyDataset(CustomDataset):

    CLASSES = ('Car', 'Truck', 'Pedestrian', 'Cyclist')

    ##### self.data_root: /content/kitti_tiny/ self.ann_file: /content/kitti_tiny/train.txt self.img_prefix: /content/kitti_tiny/training/image_2
    #### ann_file: /content/kitti_tiny/train.txt
    # annotation에 대한 모든 파일명을 가지고 있는 텍스트 파일을 __init__(self, ann_file)로 입력 받고, 이 self.ann_file이 load_annotations()의 인자로 입력
    def load_annotations(self, ann_file):
        print('#### self.data_root:', self.data_root, 'self.ann_file:', self.ann_file, 'self.img_prefix:', self.img_prefix)
        print('#### ann_file:', ann_file)
        cat2label = {k:i for i, k in enumerate(CLASSES)}
        image_list = mmcv.list_from_file(self.ann_file)
        # 포맷 중립 데이터를 담을 list 객체
        data_infos = []

        for image_id in image_list:
            filename = '{0:}/{1:}.jpeg'.format(self.img_prefix, image_id)
            # 원본 이미지의 너비, 높이를 image를 직접 로드하여 구함.
            image = cv2.imread(filename)
            height, width = image.shape[:2]
            # 개별 image의 annotation 정보 저장용 Dict 생성. key값 filename 에는 image의 파일명만 들어감(디렉토리는 제외)
            data_info = {'filename': str(image_id) + '.jpeg',
                         'width': width, 'height': height}
            # 개별 annotation이 있는 서브 디렉토리의 prefix 변환. 
            label_prefix = self.img_prefix.replace('image_2', 'label_2')
            # 개별 annotation 파일을 1개 line 씩 읽어서 list 로드 
            lines = mmcv.list_from_file(osp.join(label_prefix, str(image_id)+'.txt'))

            # 전체 lines를 개별 line별 공백 레벨로 parsing 하여 다시 list로 저장. content는 list의 list형태임.
            # ann 정보는 numpy array로 저장되나 텍스트 처리나 데이터 가공이 list 가 편하므로 일차적으로 list로 변환 수행.  
            content = [line.strip().split(' ') for line in lines]
            # 오브젝트의 클래스명은 bbox_names로 저장.
            bbox_names = [x[0] for x in content]
            # bbox 좌표를 저장
            bboxes = [ [float(info) for info in x[4:8]] for x in content]

            # 클래스명이 해당 사항이 없는 대상 Filtering out, 'DontCare'sms ignore로 별도 저장.
            gt_bboxes = []
            gt_labels = []
            gt_bboxes_ignore = []
            gt_labels_ignore = []

            for bbox_name, bbox in zip(bbox_names, bboxes):
                # 만약 bbox_name이 클래스명에 해당 되면, gt_bboxes와 gt_labels에 추가, 그렇지 않으면 gt_bboxes_ignore, gt_labels_ignore에 추가
                if bbox_name in cat2label:
                    gt_bboxes.append(bbox)
                    # gt_labels에는 class id를 입력
                    gt_labels.append(cat2label[bbox_name])
                else:
                    gt_bboxes_ignore.append(bbox)
                    gt_labels_ignore.append(-1)
                # 개별 image별 annotation 정보를 가지는 Dict 생성. 해당 Dict의 value값은 모두 np.array임.
                data_anno = {
                    'bboxes': np.array(gt_bboxes, dtype=np.float32).reshape(-1, 4),
                    'labels': np.array(gt_labels, dtype=np.long),
                    'bboxes_ignore': np.array(gt_bboxes_ignore, dtype=np.float32).reshape(-1, 4),
                    'labels_ignore': np.array(gt_labels_ignore, dtype=np.long)
                }
                # image에 대한 메타 정보를 가지는 data_info Dict에 'ann' key값으로 data_anno를 value로 저장. 
                data_info.update(ann=data_anno)
                # 전체 annotation 파일들에 대한 정보를 가지는 data_infos에 data_info Dict를 추가
                data_infos.append(data_info)
                
        return data_infos

# %%
### Config 설정하고 Pretrained 모델 다운로드
config_file = '/content/mmdetection/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py'
checkpoint_file = '/content/mmdetecton/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

# %%
# !cd mmdetection; mkdir checkpoints
# !wget -O /content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth http://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# Out:
# --2021-09-02 13:46:31--  http://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# Resolving download.openmmlab.com (download.openmmlab.com)... 47.88.36.78
# Connecting to download.openmmlab.com (download.openmmlab.com)|47.88.36.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167287506 (160M) [application/octet-stream]
# Saving to: ‘/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth’
#
# /content/mmdetectio 100%[===================>] 159.54M  12.5MB/s    in 13s
#
# 2021-09-02 13:46:46 (12.4 MB/s) - ‘/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth’ saved [167287506/167287506]

# %%
from mmcv import Config

cfg = Config.fromfile(config_file)
print(cfg.pretty_text)
# Out:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=80,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'CocoDataset'
# data_root = 'data/coco/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_train2017.json',
#         img_prefix='data/coco/train2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ]),
#     val=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(interval=1, metric='bbox')
# optimizer = dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=50, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]

# %%
from mmdet.apis import set_random_seed

# dataset에 대한 환경 파라미터 수정. 
cfg.dataset_type = 'KittyTinyDataset'
cfg.data_root = '/content/kitti_tiny/'

# train, val, test dataset에 대한 type, data_root, ann_file, img_prefix 환경 파라미터 수정. 
cfg.data.train.type = 'KittyTinyDataset'
cfg.data.train.data_root = '/content/kitti_tiny/'
cfg.data.train.ann_file = 'train.txt'
cfg.data.train.img_prefix = 'training/image_2'

cfg.data.val.type = 'KittyTinyDataset'
cfg.data.val.data_root = '/content/kitti_tiny/'
cfg.data.val.ann_file = 'val.txt'
cfg.data.val.img_prefix = 'training/image_2'

cfg.data.test.type = 'KittyTinyDataset'
cfg.data.test.data_root = '/content/kitti_tiny/'
cfg.data.test.ann_file = 'test.txt'
cfg.data.test.img_prefix = 'training/image_2'

# class의 갯수 수정.
cfg.model.roi_head.bbox_head.num_classes = 4
# pretrained 모델
cfg.load_from = 'checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

# 학습 weight 파일로 로그를 저장하기 위한 디렉토리 설정. 
cfg.work_dir = './tutorial_exps'

# 학습율 변경 환경 파라미터 설정. 
cfg.optimizer.lr = 0.02 / 8

cfg.lr_config.warmup = None
cfg.log_config.interval = 10

# config 수행 시마다 policy값이 없어지는 bug로 인하여 설정. 
cfg.lr_config.policy = 'step'

# Change the evaluation metric since we use customized dataset.
cfg.evaluation.metric = 'mAP'
# We can set the evaluation interval to reduce the evaluation times
cfg.evaluation.interval = 12
# We can set the checkpoint saving interval to reduce the storage cost
cfg.checkpoint_config.interval = 12

# Set seed thus the results are more reproducible
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)

# We can initialize the logger for training and have a look
# at the final config used for training
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=4,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'KittyTinyDataset'
# data_root = '/content/kitti_tiny/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='KittyTinyDataset',
#         ann_file='train.txt',
#         img_prefix='training/image_2',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ],
#         data_root='/content/kitti_tiny/'),
#     val=dict(
#         type='KittyTinyDataset',
#         ann_file='val.txt',
#         img_prefix='training/image_2',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         data_root='/content/kitti_tiny/'),
#     test=dict(
#         type='KittyTinyDataset',
#         ann_file='test.txt',
#         img_prefix='training/image_2',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         data_root='/content/kitti_tiny/'))
# evaluation = dict(interval=12, metric='mAP')
# optimizer = dict(type='SGD', lr=0.0025, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup=None,
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=12)
# log_config = dict(interval=10, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = 'checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'
# resume_from = None
# workflow = [('train', 1)]
# work_dir = './tutorial_exps'
# seed = 0
# gpu_ids = range(0, 1)

# %% [markdown]
# ### Config에서 설정한 Dataset과 Model, 동적 학습율, Pipeline 설정에 따라 모델 학습 수행.
#
# - train용 Dataset을 생성하고 이를 이용하여 학습 수행.

# %%
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector

# train용 Dataset 생성
datasets = [build_dataset(cfg.data.train)]
# Out:
# #### self.data_root: /content/kitti_tiny/ self.ann_file: /content/kitti_tiny/train.txt self.img_prefix: /content/kitti_tiny/training/image_2
# #### ann_file: /content/kitti_tiny/train.txt
# /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg/mmdet/datasets/custom.py:157: UserWarning: CustomDataset does not support filtering empty gt images.
#   'CustomDataset does not support filtering empty gt images.')

# %%
datasets
# Out:
# [
#  KittyTinyDataset Train dataset with number of images 349, and instance counts:
#  +----------+-------+-----------+-------+----------------+-------+-------------+-------+---------------+-------+
#  | category | count | category  | count | category       | count | category    | count | category      | count |
#  +----------+-------+-----------+-------+----------------+-------+-------------+-------+---------------+-------+
#  | 0 [Car]  | 1448  | 1 [Truck] | 55    | 2 [Pedestrian] | 214   | 3 [Cyclist] | 59    | -1 background | 0     |
#  +----------+-------+-----------+-------+----------------+-------+-------------+-------+---------------+-------+]

# %%
datasets[0].CLASSES
# Out:
# ('Car', 'Truck', 'Pedestrian', 'Cyclist')

# %%
model = build_detector(cfg.model, train_cfg=cfg.get('train_cfg'), test_cfg=cfg.get('test_cfg'))
model.CLASSES = datasets[0].CLASSES
# Out:
# /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg/mmdet/core/anchor/builder.py:17: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   '``build_anchor_generator`` would be deprecated soon, please use '

# %%
# 주의, config에 pretrained 모델 지정이 상대 경로로 설정됨 cfg.load_from = 'checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'
# 아래와 같이 %cd mmdetection 지정 필요. 

# %cd mmdetection

mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
# epochs는 config의 runner 파라미터로 지정됨. 기본 12회 
train_detector(model, datasets, cfg, distributed=False, validate=True)
# Out:
# [Errno 2] No such file or directory: 'mmdetection'
# /content/mmdetection
# #### self.data_root: /content/kitti_tiny/ self.ann_file: /content/kitti_tiny/val.txt self.img_prefix: /content/kitti_tiny/training/image_2
# #### ann_file: /content/kitti_tiny/val.txt
# 2021-09-02 14:47:56,281 - mmdet - INFO - load checkpoint from checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# 2021-09-02 14:47:56,282 - mmdet - INFO - Use load_from_local loader
# 2021-09-02 14:47:56,415 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.bbox_head.fc_reg.weight: copying a param with shape torch.Size([320, 1024]) from checkpoint, the shape in current model is torch.Size([16, 1024]).
# size mismatch for roi_head.bbox_head.fc_reg.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([16]).
# 2021-09-02 14:47:56,421 - mmdet - INFO - Start running, host: root@3d9d7c5ba979, work_dir: /content/mmdetection/tutorial_exps
# 2021-09-02 14:47:56,423 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2021-09-02 14:47:56,424 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg/mmdet/core/anchor/anchor_generator.py:361: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '
# 2021-09-02 14:48:02,012 - mmdet - INFO - Epoch [1][10/175]	lr: 2.500e-03, eta: 0:19:08, time: 0.550, data_time: 0.219, memory: 2231, loss_rpn_cls: 0.0421, loss_rpn_bbox: 0.0242, loss_cls: 0.8032, acc: 71.1621, loss_bbox: 0.4866, loss: 1.3561
# 2021-09-02 14:48:05,379 - mmdet - INFO - Epoch [1][20/175]	lr: 2.500e-03, eta: 0:15:21, time: 0.337, data_time: 0.013, memory: 2231, loss_rpn_cls: 0.0194, loss_rpn_bbox: 0.0181, loss_cls: 0.3143, acc: 90.5859, loss_bbox: 0.4517, loss: 0.8035
# 2021-09-02 14:48:08,744 - mmdet - INFO - Epoch [1][30/175]	lr: 2.500e-03, eta: 0:14:03, time: 0.336, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0277, loss_rpn_bbox: 0.0226, loss_cls: 0.2566, acc: 91.2598, loss_bbox: 0.3761, loss: 0.6831
# 2021-09-02 14:48:12,103 - mmdet - INFO - Epoch [1][40/175]	lr: 2.500e-03, eta: 0:13:22, time: 0.336, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0194, loss_rpn_bbox: 0.0187, loss_cls: 0.2290, acc: 91.7285, loss_bbox: 0.3379, loss: 0.6051
# 2021-09-02 14:48:15,498 - mmdet - INFO - Epoch [1][50/175]	lr: 2.500e-03, eta: 0:12:58, time: 0.339, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0114, loss_rpn_bbox: 0.0167, loss_cls: 0.2258, acc: 92.0605, loss_bbox: 0.3324, loss: 0.5863
# 2021-09-02 14:48:18,904 - mmdet - INFO - Epoch [1][60/175]	lr: 2.500e-03, eta: 0:12:41, time: 0.341, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0118, loss_rpn_bbox: 0.0138, loss_cls: 0.1647, acc: 93.6230, loss_bbox: 0.2447, loss: 0.4350
# 2021-09-02 14:48:22,320 - mmdet - INFO - Epoch [1][70/175]	lr: 2.500e-03, eta: 0:12:28, time: 0.341, data_time: 0.013, memory: 2231, loss_rpn_cls: 0.0090, loss_rpn_bbox: 0.0148, loss_cls: 0.1923, acc: 92.6758, loss_bbox: 0.2813, loss: 0.4975
# 2021-09-02 14:48:25,726 - mmdet - INFO - Epoch [1][80/175]	lr: 2.500e-03, eta: 0:12:17, time: 0.341, data_time: 0.013, memory: 2231, loss_rpn_cls: 0.0052, loss_rpn_bbox: 0.0159, loss_cls: 0.1766, acc: 93.8672, loss_bbox: 0.2772, loss: 0.4749
# 2021-09-02 14:48:29,143 - mmdet - INFO - Epoch [1][90/175]	lr: 2.500e-03, eta: 0:12:08, time: 0.342, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0064, loss_rpn_bbox: 0.0151, loss_cls: 0.1715, acc: 93.2227, loss_bbox: 0.2756, loss: 0.4686
# 2021-09-02 14:48:32,565 - mmdet - INFO - Epoch [1][100/175]	lr: 2.500e-03, eta: 0:12:00, time: 0.342, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0056, loss_rpn_bbox: 0.0125, loss_cls: 0.1397, acc: 94.8535, loss_bbox: 0.2189, loss: 0.3767
# 2021-09-02 14:48:35,995 - mmdet - INFO - Epoch [1][110/175]	lr: 2.500e-03, eta: 0:11:54, time: 0.343, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0052, loss_rpn_bbox: 0.0203, loss_cls: 0.1836, acc: 92.4023, loss_bbox: 0.3304, loss: 0.5395
# 2021-09-02 14:48:39,451 - mmdet - INFO - Epoch [1][120/175]	lr: 2.500e-03, eta: 0:11:48, time: 0.345, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0045, loss_rpn_bbox: 0.0162, loss_cls: 0.1477, acc: 94.1602, loss_bbox: 0.2463, loss: 0.4147
# 2021-09-02 14:48:42,914 - mmdet - INFO - Epoch [1][130/175]	lr: 2.500e-03, eta: 0:11:43, time: 0.346, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0082, loss_rpn_bbox: 0.0128, loss_cls: 0.1097, acc: 96.0938, loss_bbox: 0.1976, loss: 0.3284
# 2021-09-02 14:48:46,357 - mmdet - INFO - Epoch [1][140/175]	lr: 2.500e-03, eta: 0:11:37, time: 0.344, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0027, loss_rpn_bbox: 0.0101, loss_cls: 0.1036, acc: 96.1621, loss_bbox: 0.1756, loss: 0.2919
# 2021-09-02 14:48:49,812 - mmdet - INFO - Epoch [1][150/175]	lr: 2.500e-03, eta: 0:11:32, time: 0.345, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0042, loss_rpn_bbox: 0.0148, loss_cls: 0.1355, acc: 94.7949, loss_bbox: 0.2616, loss: 0.4160
# 2021-09-02 14:48:53,276 - mmdet - INFO - Epoch [1][160/175]	lr: 2.500e-03, eta: 0:11:28, time: 0.346, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0048, loss_rpn_bbox: 0.0159, loss_cls: 0.1168, acc: 95.5469, loss_bbox: 0.2374, loss: 0.3749
# 2021-09-02 14:48:56,730 - mmdet - INFO - Epoch [1][170/175]	lr: 2.500e-03, eta: 0:11:23, time: 0.345, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0022, loss_rpn_bbox: 0.0130, loss_cls: 0.1087, acc: 96.0352, loss_bbox: 0.1950, loss: 0.3189
# 2021-09-02 14:49:04,119 - mmdet - INFO - Epoch [2][10/175]	lr: 2.500e-03, eta: 0:11:21, time: 0.560, data_time: 0.219, memory: 2231, loss_rpn_cls: 0.0035, loss_rpn_bbox: 0.0142, loss_cls: 0.1001, acc: 96.2500, loss_bbox: 0.1958, loss: 0.3137
# 2021-09-02 14:49:07,597 - mmdet - INFO - Epoch [2][20/175]	lr: 2.500e-03, eta: 0:11:16, time: 0.348, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0020, loss_rpn_bbox: 0.0135, loss_cls: 0.1070, acc: 95.7715, loss_bbox: 0.2413, loss: 0.3638
# 2021-09-02 14:49:11,070 - mmdet - INFO - Epoch [2][30/175]	lr: 2.500e-03, eta: 0:11:12, time: 0.347, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0025, loss_rpn_bbox: 0.0143, loss_cls: 0.1004, acc: 96.5137, loss_bbox: 0.2126, loss: 0.3298
# 2021-09-02 14:49:14,555 - mmdet - INFO - Epoch [2][40/175]	lr: 2.500e-03, eta: 0:11:08, time: 0.349, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0027, loss_rpn_bbox: 0.0141, loss_cls: 0.0875, acc: 96.8164, loss_bbox: 0.1900, loss: 0.2943
# 2021-09-02 14:49:18,031 - mmdet - INFO - Epoch [2][50/175]	lr: 2.500e-03, eta: 0:11:04, time: 0.348, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0026, loss_rpn_bbox: 0.0124, loss_cls: 0.1024, acc: 95.9180, loss_bbox: 0.2099, loss: 0.3272
# 2021-09-02 14:49:21,510 - mmdet - INFO - Epoch [2][60/175]	lr: 2.500e-03, eta: 0:11:00, time: 0.348, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0013, loss_rpn_bbox: 0.0097, loss_cls: 0.0847, acc: 96.4844, loss_bbox: 0.1777, loss: 0.2734
# 2021-09-02 14:49:24,998 - mmdet - INFO - Epoch [2][70/175]	lr: 2.500e-03, eta: 0:10:56, time: 0.349, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0022, loss_rpn_bbox: 0.0128, loss_cls: 0.0902, acc: 96.8066, loss_bbox: 0.2122, loss: 0.3175
# 2021-09-02 14:49:28,518 - mmdet - INFO - Epoch [2][80/175]	lr: 2.500e-03, eta: 0:10:52, time: 0.352, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0018, loss_rpn_bbox: 0.0079, loss_cls: 0.0810, acc: 97.0703, loss_bbox: 0.1557, loss: 0.2463
# 2021-09-02 14:49:32,004 - mmdet - INFO - Epoch [2][90/175]	lr: 2.500e-03, eta: 0:10:48, time: 0.349, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0015, loss_rpn_bbox: 0.0096, loss_cls: 0.0733, acc: 97.0605, loss_bbox: 0.1540, loss: 0.2383
# 2021-09-02 14:49:35,519 - mmdet - INFO - Epoch [2][100/175]	lr: 2.500e-03, eta: 0:10:45, time: 0.351, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0022, loss_rpn_bbox: 0.0101, loss_cls: 0.0754, acc: 96.9922, loss_bbox: 0.1575, loss: 0.2452
# 2021-09-02 14:49:39,047 - mmdet - INFO - Epoch [2][110/175]	lr: 2.500e-03, eta: 0:10:41, time: 0.353, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0011, loss_rpn_bbox: 0.0099, loss_cls: 0.0696, acc: 97.3926, loss_bbox: 0.1618, loss: 0.2424
# 2021-09-02 14:49:42,555 - mmdet - INFO - Epoch [2][120/175]	lr: 2.500e-03, eta: 0:10:37, time: 0.351, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0009, loss_rpn_bbox: 0.0094, loss_cls: 0.0760, acc: 96.9336, loss_bbox: 0.1719, loss: 0.2583
# 2021-09-02 14:49:46,116 - mmdet - INFO - Epoch [2][130/175]	lr: 2.500e-03, eta: 0:10:34, time: 0.356, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0024, loss_rpn_bbox: 0.0102, loss_cls: 0.0782, acc: 97.1973, loss_bbox: 0.1650, loss: 0.2558
# 2021-09-02 14:49:49,636 - mmdet - INFO - Epoch [2][140/175]	lr: 2.500e-03, eta: 0:10:30, time: 0.352, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0020, loss_rpn_bbox: 0.0090, loss_cls: 0.0666, acc: 97.1387, loss_bbox: 0.1388, loss: 0.2165
# 2021-09-02 14:49:53,176 - mmdet - INFO - Epoch [2][150/175]	lr: 2.500e-03, eta: 0:10:27, time: 0.354, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0016, loss_rpn_bbox: 0.0101, loss_cls: 0.0846, acc: 96.7773, loss_bbox: 0.1812, loss: 0.2774
# 2021-09-02 14:49:56,698 - mmdet - INFO - Epoch [2][160/175]	lr: 2.500e-03, eta: 0:10:23, time: 0.352, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0008, loss_rpn_bbox: 0.0078, loss_cls: 0.0572, acc: 97.5781, loss_bbox: 0.1237, loss: 0.1895
# 2021-09-02 14:50:00,244 - mmdet - INFO - Epoch [2][170/175]	lr: 2.500e-03, eta: 0:10:20, time: 0.355, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0012, loss_rpn_bbox: 0.0082, loss_cls: 0.0606, acc: 97.7344, loss_bbox: 0.1395, loss: 0.2096
# 2021-09-02 14:50:07,754 - mmdet - INFO - Epoch [3][10/175]	lr: 2.500e-03, eta: 0:10:16, time: 0.568, data_time: 0.219, memory: 2231, loss_rpn_cls: 0.0024, loss_rpn_bbox: 0.0121, loss_cls: 0.0808, acc: 96.6797, loss_bbox: 0.1826, loss: 0.2780
# 2021-09-02 14:50:11,294 - mmdet - INFO - Epoch [3][20/175]	lr: 2.500e-03, eta: 0:10:13, time: 0.354, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0015, loss_rpn_bbox: 0.0079, loss_cls: 0.0627, acc: 97.6953, loss_bbox: 0.1361, loss: 0.2081
# 2021-09-02 14:50:14,846 - mmdet - INFO - Epoch [3][30/175]	lr: 2.500e-03, eta: 0:10:09, time: 0.355, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0018, loss_rpn_bbox: 0.0099, loss_cls: 0.0642, acc: 97.6953, loss_bbox: 0.1606, loss: 0.2365
# 2021-09-02 14:50:18,397 - mmdet - INFO - Epoch [3][40/175]	lr: 2.500e-03, eta: 0:10:06, time: 0.355, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0010, loss_rpn_bbox: 0.0072, loss_cls: 0.0597, acc: 97.6855, loss_bbox: 0.1361, loss: 0.2040
# 2021-09-02 14:50:21,967 - mmdet - INFO - Epoch [3][50/175]	lr: 2.500e-03, eta: 0:10:02, time: 0.357, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0013, loss_rpn_bbox: 0.0100, loss_cls: 0.0783, acc: 97.0508, loss_bbox: 0.1778, loss: 0.2674
# 2021-09-02 14:50:25,526 - mmdet - INFO - Epoch [3][60/175]	lr: 2.500e-03, eta: 0:09:59, time: 0.356, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0012, loss_rpn_bbox: 0.0113, loss_cls: 0.0713, acc: 97.4414, loss_bbox: 0.1943, loss: 0.2782
# 2021-09-02 14:50:29,083 - mmdet - INFO - Epoch [3][70/175]	lr: 2.500e-03, eta: 0:09:55, time: 0.356, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0011, loss_rpn_bbox: 0.0106, loss_cls: 0.0686, acc: 97.6465, loss_bbox: 0.1544, loss: 0.2347
# 2021-09-02 14:50:32,648 - mmdet - INFO - Epoch [3][80/175]	lr: 2.500e-03, eta: 0:09:52, time: 0.356, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0010, loss_rpn_bbox: 0.0099, loss_cls: 0.0588, acc: 97.8418, loss_bbox: 0.1333, loss: 0.2030
# 2021-09-02 14:50:36,212 - mmdet - INFO - Epoch [3][90/175]	lr: 2.500e-03, eta: 0:09:48, time: 0.356, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0016, loss_rpn_bbox: 0.0082, loss_cls: 0.0597, acc: 97.7441, loss_bbox: 0.1218, loss: 0.1913
# 2021-09-02 14:50:39,782 - mmdet - INFO - Epoch [3][100/175]	lr: 2.500e-03, eta: 0:09:45, time: 0.357, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0082, loss_cls: 0.0583, acc: 97.6953, loss_bbox: 0.1176, loss: 0.1846
# 2021-09-02 14:50:43,339 - mmdet - INFO - Epoch [3][110/175]	lr: 2.500e-03, eta: 0:09:41, time: 0.356, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0014, loss_rpn_bbox: 0.0084, loss_cls: 0.0529, acc: 97.7734, loss_bbox: 0.1161, loss: 0.1788
# 2021-09-02 14:50:46,923 - mmdet - INFO - Epoch [3][120/175]	lr: 2.500e-03, eta: 0:09:38, time: 0.358, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0105, loss_cls: 0.0662, acc: 97.5000, loss_bbox: 0.1498, loss: 0.2271
# 2021-09-02 14:50:50,480 - mmdet - INFO - Epoch [3][130/175]	lr: 2.500e-03, eta: 0:09:34, time: 0.356, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0008, loss_rpn_bbox: 0.0081, loss_cls: 0.0516, acc: 98.0176, loss_bbox: 0.1228, loss: 0.1833
# 2021-09-02 14:50:54,051 - mmdet - INFO - Epoch [3][140/175]	lr: 2.500e-03, eta: 0:09:31, time: 0.357, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0009, loss_rpn_bbox: 0.0091, loss_cls: 0.0527, acc: 98.2031, loss_bbox: 0.1265, loss: 0.1892
# 2021-09-02 14:50:57,644 - mmdet - INFO - Epoch [3][150/175]	lr: 2.500e-03, eta: 0:09:28, time: 0.359, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0020, loss_rpn_bbox: 0.0100, loss_cls: 0.0561, acc: 97.6465, loss_bbox: 0.1287, loss: 0.1967
# 2021-09-02 14:51:01,240 - mmdet - INFO - Epoch [3][160/175]	lr: 2.500e-03, eta: 0:09:24, time: 0.360, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0068, loss_cls: 0.0460, acc: 98.2129, loss_bbox: 0.1172, loss: 0.1706
# 2021-09-02 14:51:04,817 - mmdet - INFO - Epoch [3][170/175]	lr: 2.500e-03, eta: 0:09:21, time: 0.358, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0068, loss_cls: 0.0437, acc: 98.2812, loss_bbox: 0.1229, loss: 0.1739
# 2021-09-02 14:51:12,349 - mmdet - INFO - Epoch [4][10/175]	lr: 2.500e-03, eta: 0:09:16, time: 0.568, data_time: 0.218, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0076, loss_cls: 0.0520, acc: 98.2520, loss_bbox: 0.1329, loss: 0.1932
# 2021-09-02 14:51:15,934 - mmdet - INFO - Epoch [4][20/175]	lr: 2.500e-03, eta: 0:09:13, time: 0.358, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0083, loss_cls: 0.0514, acc: 98.0859, loss_bbox: 0.1180, loss: 0.1784
# 2021-09-02 14:51:19,532 - mmdet - INFO - Epoch [4][30/175]	lr: 2.500e-03, eta: 0:09:09, time: 0.360, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0022, loss_rpn_bbox: 0.0061, loss_cls: 0.0413, acc: 98.4863, loss_bbox: 0.0976, loss: 0.1472
# 2021-09-02 14:51:23,115 - mmdet - INFO - Epoch [4][40/175]	lr: 2.500e-03, eta: 0:09:06, time: 0.358, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0076, loss_cls: 0.0471, acc: 98.2520, loss_bbox: 0.1156, loss: 0.1709
# 2021-09-02 14:51:26,713 - mmdet - INFO - Epoch [4][50/175]	lr: 2.500e-03, eta: 0:09:02, time: 0.360, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0072, loss_cls: 0.0458, acc: 98.3398, loss_bbox: 0.1075, loss: 0.1613
# 2021-09-02 14:51:30,302 - mmdet - INFO - Epoch [4][60/175]	lr: 2.500e-03, eta: 0:08:59, time: 0.359, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0014, loss_rpn_bbox: 0.0080, loss_cls: 0.0520, acc: 98.1934, loss_bbox: 0.1139, loss: 0.1753
# 2021-09-02 14:51:33,893 - mmdet - INFO - Epoch [4][70/175]	lr: 2.500e-03, eta: 0:08:56, time: 0.359, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0010, loss_rpn_bbox: 0.0074, loss_cls: 0.0462, acc: 98.3301, loss_bbox: 0.1203, loss: 0.1750
# 2021-09-02 14:51:37,487 - mmdet - INFO - Epoch [4][80/175]	lr: 2.500e-03, eta: 0:08:52, time: 0.359, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0083, loss_cls: 0.0457, acc: 98.3691, loss_bbox: 0.1213, loss: 0.1757
# 2021-09-02 14:51:41,089 - mmdet - INFO - Epoch [4][90/175]	lr: 2.500e-03, eta: 0:08:49, time: 0.360, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0014, loss_rpn_bbox: 0.0072, loss_cls: 0.0447, acc: 98.4277, loss_bbox: 0.0946, loss: 0.1479
# 2021-09-02 14:51:44,680 - mmdet - INFO - Epoch [4][100/175]	lr: 2.500e-03, eta: 0:08:45, time: 0.359, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0010, loss_rpn_bbox: 0.0072, loss_cls: 0.0391, acc: 98.6035, loss_bbox: 0.0940, loss: 0.1413
# 2021-09-02 14:51:48,275 - mmdet - INFO - Epoch [4][110/175]	lr: 2.500e-03, eta: 0:08:42, time: 0.360, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0011, loss_rpn_bbox: 0.0068, loss_cls: 0.0415, acc: 98.5156, loss_bbox: 0.0964, loss: 0.1458
# 2021-09-02 14:51:51,882 - mmdet - INFO - Epoch [4][120/175]	lr: 2.500e-03, eta: 0:08:38, time: 0.360, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0085, loss_cls: 0.0438, acc: 98.4375, loss_bbox: 0.1108, loss: 0.1637
# 2021-09-02 14:51:55,499 - mmdet - INFO - Epoch [4][130/175]	lr: 2.500e-03, eta: 0:08:35, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0010, loss_rpn_bbox: 0.0081, loss_cls: 0.0484, acc: 98.1348, loss_bbox: 0.1265, loss: 0.1841
# 2021-09-02 14:51:59,121 - mmdet - INFO - Epoch [4][140/175]	lr: 2.500e-03, eta: 0:08:31, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0009, loss_rpn_bbox: 0.0081, loss_cls: 0.0420, acc: 98.5938, loss_bbox: 0.1078, loss: 0.1588
# 2021-09-02 14:52:02,724 - mmdet - INFO - Epoch [4][150/175]	lr: 2.500e-03, eta: 0:08:28, time: 0.360, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0062, loss_cls: 0.0355, acc: 98.8086, loss_bbox: 0.0898, loss: 0.1319
# 2021-09-02 14:52:06,329 - mmdet - INFO - Epoch [4][160/175]	lr: 2.500e-03, eta: 0:08:24, time: 0.361, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0008, loss_rpn_bbox: 0.0070, loss_cls: 0.0414, acc: 98.5938, loss_bbox: 0.0963, loss: 0.1455
# 2021-09-02 14:52:09,956 - mmdet - INFO - Epoch [4][170/175]	lr: 2.500e-03, eta: 0:08:21, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0087, loss_cls: 0.0447, acc: 98.4668, loss_bbox: 0.1129, loss: 0.1669
# 2021-09-02 14:52:17,560 - mmdet - INFO - Epoch [5][10/175]	lr: 2.500e-03, eta: 0:08:16, time: 0.574, data_time: 0.218, memory: 2231, loss_rpn_cls: 0.0012, loss_rpn_bbox: 0.0066, loss_cls: 0.0429, acc: 98.3594, loss_bbox: 0.1102, loss: 0.1609
# 2021-09-02 14:52:21,181 - mmdet - INFO - Epoch [5][20/175]	lr: 2.500e-03, eta: 0:08:13, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0013, loss_rpn_bbox: 0.0069, loss_cls: 0.0433, acc: 98.2910, loss_bbox: 0.1083, loss: 0.1597
# 2021-09-02 14:52:24,784 - mmdet - INFO - Epoch [5][30/175]	lr: 2.500e-03, eta: 0:08:09, time: 0.360, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0081, loss_cls: 0.0455, acc: 98.3105, loss_bbox: 0.1111, loss: 0.1650
# 2021-09-02 14:52:28,400 - mmdet - INFO - Epoch [5][40/175]	lr: 2.500e-03, eta: 0:08:06, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0071, loss_cls: 0.0389, acc: 98.4473, loss_bbox: 0.1037, loss: 0.1503
# 2021-09-02 14:52:32,013 - mmdet - INFO - Epoch [5][50/175]	lr: 2.500e-03, eta: 0:08:02, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0008, loss_rpn_bbox: 0.0082, loss_cls: 0.0493, acc: 98.0957, loss_bbox: 0.1187, loss: 0.1770
# 2021-09-02 14:52:35,641 - mmdet - INFO - Epoch [5][60/175]	lr: 2.500e-03, eta: 0:07:59, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0013, loss_rpn_bbox: 0.0082, loss_cls: 0.0471, acc: 98.4180, loss_bbox: 0.1224, loss: 0.1790
# 2021-09-02 14:52:39,246 - mmdet - INFO - Epoch [5][70/175]	lr: 2.500e-03, eta: 0:07:55, time: 0.361, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0071, loss_cls: 0.0364, acc: 98.7793, loss_bbox: 0.0838, loss: 0.1280
# 2021-09-02 14:52:42,866 - mmdet - INFO - Epoch [5][80/175]	lr: 2.500e-03, eta: 0:07:52, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0066, loss_cls: 0.0343, acc: 98.6719, loss_bbox: 0.1045, loss: 0.1460
# 2021-09-02 14:52:46,479 - mmdet - INFO - Epoch [5][90/175]	lr: 2.500e-03, eta: 0:07:48, time: 0.361, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0093, loss_cls: 0.0337, acc: 98.7500, loss_bbox: 0.0895, loss: 0.1330
# 2021-09-02 14:52:50,070 - mmdet - INFO - Epoch [5][100/175]	lr: 2.500e-03, eta: 0:07:45, time: 0.359, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0056, loss_cls: 0.0332, acc: 98.7402, loss_bbox: 0.0783, loss: 0.1175
# 2021-09-02 14:52:53,705 - mmdet - INFO - Epoch [5][110/175]	lr: 2.500e-03, eta: 0:07:41, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0009, loss_rpn_bbox: 0.0084, loss_cls: 0.0444, acc: 98.2324, loss_bbox: 0.1047, loss: 0.1584
# 2021-09-02 14:52:57,322 - mmdet - INFO - Epoch [5][120/175]	lr: 2.500e-03, eta: 0:07:38, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0066, loss_cls: 0.0381, acc: 98.7207, loss_bbox: 0.0979, loss: 0.1430
# 2021-09-02 14:53:00,954 - mmdet - INFO - Epoch [5][130/175]	lr: 2.500e-03, eta: 0:07:34, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0019, loss_rpn_bbox: 0.0083, loss_cls: 0.0416, acc: 98.4082, loss_bbox: 0.1003, loss: 0.1520
# 2021-09-02 14:53:04,586 - mmdet - INFO - Epoch [5][140/175]	lr: 2.500e-03, eta: 0:07:31, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0060, loss_cls: 0.0315, acc: 98.8574, loss_bbox: 0.0826, loss: 0.1207
# 2021-09-02 14:53:08,210 - mmdet - INFO - Epoch [5][150/175]	lr: 2.500e-03, eta: 0:07:27, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0011, loss_rpn_bbox: 0.0063, loss_cls: 0.0358, acc: 98.6426, loss_bbox: 0.0884, loss: 0.1316
# 2021-09-02 14:53:11,841 - mmdet - INFO - Epoch [5][160/175]	lr: 2.500e-03, eta: 0:07:24, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0009, loss_rpn_bbox: 0.0058, loss_cls: 0.0330, acc: 98.7012, loss_bbox: 0.0799, loss: 0.1197
# 2021-09-02 14:53:15,467 - mmdet - INFO - Epoch [5][170/175]	lr: 2.500e-03, eta: 0:07:20, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0009, loss_rpn_bbox: 0.0052, loss_cls: 0.0304, acc: 99.0430, loss_bbox: 0.0930, loss: 0.1295
# 2021-09-02 14:53:23,086 - mmdet - INFO - Epoch [6][10/175]	lr: 2.500e-03, eta: 0:07:15, time: 0.576, data_time: 0.218, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0061, loss_cls: 0.0376, acc: 98.6328, loss_bbox: 0.1068, loss: 0.1510
# 2021-09-02 14:53:26,715 - mmdet - INFO - Epoch [6][20/175]	lr: 2.500e-03, eta: 0:07:12, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0062, loss_cls: 0.0398, acc: 98.3691, loss_bbox: 0.0929, loss: 0.1392
# 2021-09-02 14:53:30,350 - mmdet - INFO - Epoch [6][30/175]	lr: 2.500e-03, eta: 0:07:08, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0073, loss_cls: 0.0355, acc: 98.8281, loss_bbox: 0.0964, loss: 0.1398
# 2021-09-02 14:53:33,964 - mmdet - INFO - Epoch [6][40/175]	lr: 2.500e-03, eta: 0:07:05, time: 0.361, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0048, loss_cls: 0.0283, acc: 98.9941, loss_bbox: 0.0772, loss: 0.1109
# 2021-09-02 14:53:37,590 - mmdet - INFO - Epoch [6][50/175]	lr: 2.500e-03, eta: 0:07:01, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0055, loss_cls: 0.0325, acc: 98.7598, loss_bbox: 0.0771, loss: 0.1154
# 2021-09-02 14:53:41,210 - mmdet - INFO - Epoch [6][60/175]	lr: 2.500e-03, eta: 0:06:58, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0065, loss_cls: 0.0356, acc: 98.5938, loss_bbox: 0.0847, loss: 0.1275
# 2021-09-02 14:53:44,817 - mmdet - INFO - Epoch [6][70/175]	lr: 2.500e-03, eta: 0:06:54, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0045, loss_cls: 0.0252, acc: 99.0430, loss_bbox: 0.0672, loss: 0.0971
# 2021-09-02 14:53:48,436 - mmdet - INFO - Epoch [6][80/175]	lr: 2.500e-03, eta: 0:06:50, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0053, loss_cls: 0.0315, acc: 98.6523, loss_bbox: 0.0788, loss: 0.1160
# 2021-09-02 14:53:52,057 - mmdet - INFO - Epoch [6][90/175]	lr: 2.500e-03, eta: 0:06:47, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0059, loss_cls: 0.0343, acc: 98.7598, loss_bbox: 0.0804, loss: 0.1212
# 2021-09-02 14:53:55,687 - mmdet - INFO - Epoch [6][100/175]	lr: 2.500e-03, eta: 0:06:43, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0083, loss_cls: 0.0421, acc: 98.4375, loss_bbox: 0.1113, loss: 0.1623
# 2021-09-02 14:53:59,302 - mmdet - INFO - Epoch [6][110/175]	lr: 2.500e-03, eta: 0:06:40, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0074, loss_cls: 0.0394, acc: 98.4766, loss_bbox: 0.1016, loss: 0.1489
# 2021-09-02 14:54:02,934 - mmdet - INFO - Epoch [6][120/175]	lr: 2.500e-03, eta: 0:06:36, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0012, loss_rpn_bbox: 0.0058, loss_cls: 0.0343, acc: 98.8379, loss_bbox: 0.0888, loss: 0.1301
# 2021-09-02 14:54:06,577 - mmdet - INFO - Epoch [6][130/175]	lr: 2.500e-03, eta: 0:06:33, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0056, loss_cls: 0.0375, acc: 98.3887, loss_bbox: 0.0876, loss: 0.1310
# 2021-09-02 14:54:10,212 - mmdet - INFO - Epoch [6][140/175]	lr: 2.500e-03, eta: 0:06:29, time: 0.364, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0055, loss_cls: 0.0336, acc: 98.7305, loss_bbox: 0.0813, loss: 0.1207
# 2021-09-02 14:54:13,872 - mmdet - INFO - Epoch [6][150/175]	lr: 2.500e-03, eta: 0:06:26, time: 0.366, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0010, loss_rpn_bbox: 0.0065, loss_cls: 0.0338, acc: 98.6035, loss_bbox: 0.0943, loss: 0.1356
# 2021-09-02 14:54:17,497 - mmdet - INFO - Epoch [6][160/175]	lr: 2.500e-03, eta: 0:06:22, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0010, loss_rpn_bbox: 0.0060, loss_cls: 0.0371, acc: 98.5254, loss_bbox: 0.0994, loss: 0.1435
# 2021-09-02 14:54:21,158 - mmdet - INFO - Epoch [6][170/175]	lr: 2.500e-03, eta: 0:06:19, time: 0.366, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0076, loss_cls: 0.0361, acc: 98.6816, loss_bbox: 0.1123, loss: 0.1565
# 2021-09-02 14:54:28,780 - mmdet - INFO - Epoch [7][10/175]	lr: 2.500e-03, eta: 0:06:14, time: 0.577, data_time: 0.218, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0071, loss_cls: 0.0429, acc: 98.2910, loss_bbox: 0.1034, loss: 0.1541
# 2021-09-02 14:54:32,428 - mmdet - INFO - Epoch [7][20/175]	lr: 2.500e-03, eta: 0:06:10, time: 0.365, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0066, loss_cls: 0.0344, acc: 98.7305, loss_bbox: 0.0983, loss: 0.1399
# 2021-09-02 14:54:36,055 - mmdet - INFO - Epoch [7][30/175]	lr: 2.500e-03, eta: 0:06:06, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0064, loss_cls: 0.0369, acc: 98.6230, loss_bbox: 0.0954, loss: 0.1395
# 2021-09-02 14:54:39,663 - mmdet - INFO - Epoch [7][40/175]	lr: 2.500e-03, eta: 0:06:03, time: 0.361, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0057, loss_cls: 0.0344, acc: 98.7793, loss_bbox: 0.0800, loss: 0.1204
# 2021-09-02 14:54:43,280 - mmdet - INFO - Epoch [7][50/175]	lr: 2.500e-03, eta: 0:05:59, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0047, loss_cls: 0.0285, acc: 98.9746, loss_bbox: 0.0714, loss: 0.1049
# 2021-09-02 14:54:46,912 - mmdet - INFO - Epoch [7][60/175]	lr: 2.500e-03, eta: 0:05:56, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0050, loss_cls: 0.0273, acc: 99.1895, loss_bbox: 0.0724, loss: 0.1052
# 2021-09-02 14:54:50,537 - mmdet - INFO - Epoch [7][70/175]	lr: 2.500e-03, eta: 0:05:52, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0072, loss_cls: 0.0338, acc: 98.8086, loss_bbox: 0.0898, loss: 0.1314
# 2021-09-02 14:54:54,158 - mmdet - INFO - Epoch [7][80/175]	lr: 2.500e-03, eta: 0:05:49, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0010, loss_rpn_bbox: 0.0062, loss_cls: 0.0332, acc: 98.8281, loss_bbox: 0.0821, loss: 0.1225
# 2021-09-02 14:54:57,788 - mmdet - INFO - Epoch [7][90/175]	lr: 2.500e-03, eta: 0:05:45, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0013, loss_rpn_bbox: 0.0056, loss_cls: 0.0322, acc: 98.9160, loss_bbox: 0.0838, loss: 0.1230
# 2021-09-02 14:55:01,415 - mmdet - INFO - Epoch [7][100/175]	lr: 2.500e-03, eta: 0:05:41, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0046, loss_cls: 0.0272, acc: 99.0918, loss_bbox: 0.0774, loss: 0.1096
# 2021-09-02 14:55:05,042 - mmdet - INFO - Epoch [7][110/175]	lr: 2.500e-03, eta: 0:05:38, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0052, loss_cls: 0.0288, acc: 98.9551, loss_bbox: 0.0811, loss: 0.1154
# 2021-09-02 14:55:08,685 - mmdet - INFO - Epoch [7][120/175]	lr: 2.500e-03, eta: 0:05:34, time: 0.364, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0063, loss_cls: 0.0315, acc: 98.8184, loss_bbox: 0.0957, loss: 0.1340
# 2021-09-02 14:55:12,308 - mmdet - INFO - Epoch [7][130/175]	lr: 2.500e-03, eta: 0:05:31, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0010, loss_rpn_bbox: 0.0054, loss_cls: 0.0313, acc: 98.7988, loss_bbox: 0.0901, loss: 0.1278
# 2021-09-02 14:55:15,940 - mmdet - INFO - Epoch [7][140/175]	lr: 2.500e-03, eta: 0:05:27, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0008, loss_rpn_bbox: 0.0064, loss_cls: 0.0323, acc: 98.9746, loss_bbox: 0.0929, loss: 0.1323
# 2021-09-02 14:55:19,569 - mmdet - INFO - Epoch [7][150/175]	lr: 2.500e-03, eta: 0:05:24, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0077, loss_cls: 0.0326, acc: 98.8867, loss_bbox: 0.0921, loss: 0.1329
# 2021-09-02 14:55:23,201 - mmdet - INFO - Epoch [7][160/175]	lr: 2.500e-03, eta: 0:05:20, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0061, loss_cls: 0.0318, acc: 98.7793, loss_bbox: 0.0800, loss: 0.1181
# 2021-09-02 14:55:26,839 - mmdet - INFO - Epoch [7][170/175]	lr: 2.500e-03, eta: 0:05:16, time: 0.364, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0057, loss_cls: 0.0313, acc: 98.7109, loss_bbox: 0.0832, loss: 0.1205
# 2021-09-02 14:55:34,471 - mmdet - INFO - Epoch [8][10/175]	lr: 2.500e-03, eta: 0:05:11, time: 0.578, data_time: 0.220, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0073, loss_cls: 0.0309, acc: 98.8184, loss_bbox: 0.0814, loss: 0.1201
# 2021-09-02 14:55:38,102 - mmdet - INFO - Epoch [8][20/175]	lr: 2.500e-03, eta: 0:05:08, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0008, loss_rpn_bbox: 0.0050, loss_cls: 0.0266, acc: 99.0527, loss_bbox: 0.0649, loss: 0.0974
# 2021-09-02 14:55:41,708 - mmdet - INFO - Epoch [8][30/175]	lr: 2.500e-03, eta: 0:05:04, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0009, loss_rpn_bbox: 0.0047, loss_cls: 0.0299, acc: 98.8867, loss_bbox: 0.0737, loss: 0.1091
# 2021-09-02 14:55:45,336 - mmdet - INFO - Epoch [8][40/175]	lr: 2.500e-03, eta: 0:05:00, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0052, loss_cls: 0.0342, acc: 98.7109, loss_bbox: 0.0894, loss: 0.1291
# 2021-09-02 14:55:48,954 - mmdet - INFO - Epoch [8][50/175]	lr: 2.500e-03, eta: 0:04:57, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0061, loss_cls: 0.0310, acc: 98.9062, loss_bbox: 0.0791, loss: 0.1167
# 2021-09-02 14:55:52,570 - mmdet - INFO - Epoch [8][60/175]	lr: 2.500e-03, eta: 0:04:53, time: 0.361, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0062, loss_cls: 0.0350, acc: 98.7988, loss_bbox: 0.0861, loss: 0.1278
# 2021-09-02 14:55:56,182 - mmdet - INFO - Epoch [8][70/175]	lr: 2.500e-03, eta: 0:04:50, time: 0.361, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0009, loss_rpn_bbox: 0.0045, loss_cls: 0.0292, acc: 98.8574, loss_bbox: 0.0647, loss: 0.0992
# 2021-09-02 14:55:59,796 - mmdet - INFO - Epoch [8][80/175]	lr: 2.500e-03, eta: 0:04:46, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0052, loss_cls: 0.0248, acc: 99.1113, loss_bbox: 0.0623, loss: 0.0927
# 2021-09-02 14:56:03,419 - mmdet - INFO - Epoch [8][90/175]	lr: 2.500e-03, eta: 0:04:42, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0048, loss_cls: 0.0291, acc: 98.8965, loss_bbox: 0.0600, loss: 0.0944
# 2021-09-02 14:56:07,048 - mmdet - INFO - Epoch [8][100/175]	lr: 2.500e-03, eta: 0:04:39, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0052, loss_cls: 0.0329, acc: 98.7793, loss_bbox: 0.0822, loss: 0.1207
# 2021-09-02 14:56:10,677 - mmdet - INFO - Epoch [8][110/175]	lr: 2.500e-03, eta: 0:04:35, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0053, loss_cls: 0.0305, acc: 98.9844, loss_bbox: 0.0761, loss: 0.1123
# 2021-09-02 14:56:14,292 - mmdet - INFO - Epoch [8][120/175]	lr: 2.500e-03, eta: 0:04:32, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0032, loss_cls: 0.0245, acc: 99.0527, loss_bbox: 0.0586, loss: 0.0866
# 2021-09-02 14:56:17,919 - mmdet - INFO - Epoch [8][130/175]	lr: 2.500e-03, eta: 0:04:28, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0052, loss_cls: 0.0319, acc: 98.7988, loss_bbox: 0.0846, loss: 0.1219
# 2021-09-02 14:56:21,532 - mmdet - INFO - Epoch [8][140/175]	lr: 2.500e-03, eta: 0:04:24, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0008, loss_rpn_bbox: 0.0058, loss_cls: 0.0358, acc: 98.7695, loss_bbox: 0.0918, loss: 0.1343
# 2021-09-02 14:56:25,162 - mmdet - INFO - Epoch [8][150/175]	lr: 2.500e-03, eta: 0:04:21, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0058, loss_cls: 0.0353, acc: 98.6621, loss_bbox: 0.0887, loss: 0.1302
# 2021-09-02 14:56:28,772 - mmdet - INFO - Epoch [8][160/175]	lr: 2.500e-03, eta: 0:04:17, time: 0.361, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0043, loss_cls: 0.0307, acc: 98.7402, loss_bbox: 0.0780, loss: 0.1132
# 2021-09-02 14:56:32,389 - mmdet - INFO - Epoch [8][170/175]	lr: 2.500e-03, eta: 0:04:14, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0046, loss_cls: 0.0247, acc: 99.0625, loss_bbox: 0.0633, loss: 0.0931
# 2021-09-02 14:56:39,989 - mmdet - INFO - Epoch [9][10/175]	lr: 2.500e-04, eta: 0:04:08, time: 0.574, data_time: 0.218, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0051, loss_cls: 0.0296, acc: 99.0137, loss_bbox: 0.0741, loss: 0.1094
# 2021-09-02 14:56:43,614 - mmdet - INFO - Epoch [9][20/175]	lr: 2.500e-04, eta: 0:04:05, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0007, loss_rpn_bbox: 0.0044, loss_cls: 0.0291, acc: 98.9453, loss_bbox: 0.0613, loss: 0.0954
# 2021-09-02 14:56:47,244 - mmdet - INFO - Epoch [9][30/175]	lr: 2.500e-04, eta: 0:04:01, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0031, loss_cls: 0.0197, acc: 99.3359, loss_bbox: 0.0444, loss: 0.0676
# 2021-09-02 14:56:50,851 - mmdet - INFO - Epoch [9][40/175]	lr: 2.500e-04, eta: 0:03:58, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0038, loss_cls: 0.0263, acc: 99.1016, loss_bbox: 0.0580, loss: 0.0885
# 2021-09-02 14:56:54,457 - mmdet - INFO - Epoch [9][50/175]	lr: 2.500e-04, eta: 0:03:54, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0012, loss_rpn_bbox: 0.0038, loss_cls: 0.0287, acc: 99.0234, loss_bbox: 0.0607, loss: 0.0944
# 2021-09-02 14:56:58,090 - mmdet - INFO - Epoch [9][60/175]	lr: 2.500e-04, eta: 0:03:50, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0036, loss_cls: 0.0281, acc: 99.0723, loss_bbox: 0.0584, loss: 0.0905
# 2021-09-02 14:57:01,724 - mmdet - INFO - Epoch [9][70/175]	lr: 2.500e-04, eta: 0:03:47, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0013, loss_rpn_bbox: 0.0043, loss_cls: 0.0289, acc: 98.9160, loss_bbox: 0.0708, loss: 0.1053
# 2021-09-02 14:57:05,347 - mmdet - INFO - Epoch [9][80/175]	lr: 2.500e-04, eta: 0:03:43, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0044, loss_cls: 0.0336, acc: 98.8184, loss_bbox: 0.0696, loss: 0.1083
# 2021-09-02 14:57:08,964 - mmdet - INFO - Epoch [9][90/175]	lr: 2.500e-04, eta: 0:03:40, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0036, loss_cls: 0.0235, acc: 99.3652, loss_bbox: 0.0522, loss: 0.0798
# 2021-09-02 14:57:12,612 - mmdet - INFO - Epoch [9][100/175]	lr: 2.500e-04, eta: 0:03:36, time: 0.365, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0014, loss_rpn_bbox: 0.0044, loss_cls: 0.0317, acc: 98.9746, loss_bbox: 0.0703, loss: 0.1078
# 2021-09-02 14:57:16,242 - mmdet - INFO - Epoch [9][110/175]	lr: 2.500e-04, eta: 0:03:32, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0034, loss_cls: 0.0234, acc: 99.3359, loss_bbox: 0.0494, loss: 0.0767
# 2021-09-02 14:57:19,889 - mmdet - INFO - Epoch [9][120/175]	lr: 2.500e-04, eta: 0:03:29, time: 0.365, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0035, loss_cls: 0.0291, acc: 99.0332, loss_bbox: 0.0551, loss: 0.0882
# 2021-09-02 14:57:23,524 - mmdet - INFO - Epoch [9][130/175]	lr: 2.500e-04, eta: 0:03:25, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0034, loss_cls: 0.0255, acc: 99.1309, loss_bbox: 0.0505, loss: 0.0797
# 2021-09-02 14:57:27,159 - mmdet - INFO - Epoch [9][140/175]	lr: 2.500e-04, eta: 0:03:22, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0033, loss_cls: 0.0249, acc: 99.2480, loss_bbox: 0.0506, loss: 0.0792
# 2021-09-02 14:57:30,784 - mmdet - INFO - Epoch [9][150/175]	lr: 2.500e-04, eta: 0:03:18, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0028, loss_cls: 0.0187, acc: 99.4824, loss_bbox: 0.0424, loss: 0.0642
# 2021-09-02 14:57:34,403 - mmdet - INFO - Epoch [9][160/175]	lr: 2.500e-04, eta: 0:03:14, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0034, loss_cls: 0.0250, acc: 99.1504, loss_bbox: 0.0472, loss: 0.0762
# 2021-09-02 14:57:38,023 - mmdet - INFO - Epoch [9][170/175]	lr: 2.500e-04, eta: 0:03:11, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0032, loss_cls: 0.0219, acc: 99.2871, loss_bbox: 0.0398, loss: 0.0656
# 2021-09-02 14:57:45,595 - mmdet - INFO - Epoch [10][10/175]	lr: 2.500e-04, eta: 0:03:06, time: 0.572, data_time: 0.218, memory: 2231, loss_rpn_cls: 0.0008, loss_rpn_bbox: 0.0030, loss_cls: 0.0252, acc: 99.1797, loss_bbox: 0.0514, loss: 0.0805
# 2021-09-02 14:57:49,220 - mmdet - INFO - Epoch [10][20/175]	lr: 2.500e-04, eta: 0:03:02, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0025, loss_cls: 0.0191, acc: 99.4141, loss_bbox: 0.0399, loss: 0.0618
# 2021-09-02 14:57:52,844 - mmdet - INFO - Epoch [10][30/175]	lr: 2.500e-04, eta: 0:02:58, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0032, loss_cls: 0.0243, acc: 99.2383, loss_bbox: 0.0485, loss: 0.0763
# 2021-09-02 14:57:56,490 - mmdet - INFO - Epoch [10][40/175]	lr: 2.500e-04, eta: 0:02:55, time: 0.365, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0039, loss_cls: 0.0320, acc: 98.9746, loss_bbox: 0.0625, loss: 0.0989
# 2021-09-02 14:58:00,103 - mmdet - INFO - Epoch [10][50/175]	lr: 2.500e-04, eta: 0:02:51, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0010, loss_rpn_bbox: 0.0030, loss_cls: 0.0239, acc: 99.2676, loss_bbox: 0.0505, loss: 0.0784
# 2021-09-02 14:58:03,718 - mmdet - INFO - Epoch [10][60/175]	lr: 2.500e-04, eta: 0:02:47, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0030, loss_cls: 0.0232, acc: 99.3066, loss_bbox: 0.0498, loss: 0.0763
# 2021-09-02 14:58:07,329 - mmdet - INFO - Epoch [10][70/175]	lr: 2.500e-04, eta: 0:02:44, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0031, loss_cls: 0.0220, acc: 99.2871, loss_bbox: 0.0423, loss: 0.0676
# 2021-09-02 14:58:10,950 - mmdet - INFO - Epoch [10][80/175]	lr: 2.500e-04, eta: 0:02:40, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0031, loss_cls: 0.0233, acc: 99.2969, loss_bbox: 0.0472, loss: 0.0738
# 2021-09-02 14:58:14,570 - mmdet - INFO - Epoch [10][90/175]	lr: 2.500e-04, eta: 0:02:37, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0008, loss_rpn_bbox: 0.0030, loss_cls: 0.0242, acc: 99.2480, loss_bbox: 0.0449, loss: 0.0729
# 2021-09-02 14:58:18,209 - mmdet - INFO - Epoch [10][100/175]	lr: 2.500e-04, eta: 0:02:33, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0008, loss_rpn_bbox: 0.0033, loss_cls: 0.0256, acc: 99.1895, loss_bbox: 0.0505, loss: 0.0802
# 2021-09-02 14:58:21,839 - mmdet - INFO - Epoch [10][110/175]	lr: 2.500e-04, eta: 0:02:29, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0034, loss_cls: 0.0248, acc: 99.2090, loss_bbox: 0.0487, loss: 0.0773
# 2021-09-02 14:58:25,462 - mmdet - INFO - Epoch [10][120/175]	lr: 2.500e-04, eta: 0:02:26, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0020, loss_cls: 0.0201, acc: 99.3750, loss_bbox: 0.0379, loss: 0.0602
# 2021-09-02 14:58:29,098 - mmdet - INFO - Epoch [10][130/175]	lr: 2.500e-04, eta: 0:02:22, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0019, loss_cls: 0.0207, acc: 99.3164, loss_bbox: 0.0362, loss: 0.0591
# 2021-09-02 14:58:32,722 - mmdet - INFO - Epoch [10][140/175]	lr: 2.500e-04, eta: 0:02:19, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0033, loss_cls: 0.0235, acc: 99.2188, loss_bbox: 0.0452, loss: 0.0724
# 2021-09-02 14:58:36,361 - mmdet - INFO - Epoch [10][150/175]	lr: 2.500e-04, eta: 0:02:15, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0026, loss_cls: 0.0204, acc: 99.3652, loss_bbox: 0.0384, loss: 0.0617
# 2021-09-02 14:58:39,986 - mmdet - INFO - Epoch [10][160/175]	lr: 2.500e-04, eta: 0:02:11, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0028, loss_cls: 0.0247, acc: 99.2480, loss_bbox: 0.0467, loss: 0.0744
# 2021-09-02 14:58:43,600 - mmdet - INFO - Epoch [10][170/175]	lr: 2.500e-04, eta: 0:02:08, time: 0.361, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0032, loss_cls: 0.0255, acc: 99.1309, loss_bbox: 0.0478, loss: 0.0768
# 2021-09-02 14:58:51,218 - mmdet - INFO - Epoch [11][10/175]	lr: 2.500e-04, eta: 0:02:02, time: 0.576, data_time: 0.218, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0036, loss_cls: 0.0273, acc: 99.2188, loss_bbox: 0.0542, loss: 0.0853
# 2021-09-02 14:58:54,838 - mmdet - INFO - Epoch [11][20/175]	lr: 2.500e-04, eta: 0:01:59, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0022, loss_cls: 0.0179, acc: 99.4531, loss_bbox: 0.0338, loss: 0.0542
# 2021-09-02 14:58:58,451 - mmdet - INFO - Epoch [11][30/175]	lr: 2.500e-04, eta: 0:01:55, time: 0.361, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0022, loss_cls: 0.0207, acc: 99.3457, loss_bbox: 0.0371, loss: 0.0603
# 2021-09-02 14:59:02,084 - mmdet - INFO - Epoch [11][40/175]	lr: 2.500e-04, eta: 0:01:52, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0030, loss_cls: 0.0221, acc: 99.3555, loss_bbox: 0.0497, loss: 0.0751
# 2021-09-02 14:59:05,712 - mmdet - INFO - Epoch [11][50/175]	lr: 2.500e-04, eta: 0:01:48, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0028, loss_cls: 0.0273, acc: 99.0820, loss_bbox: 0.0514, loss: 0.0819
# 2021-09-02 14:59:09,358 - mmdet - INFO - Epoch [11][60/175]	lr: 2.500e-04, eta: 0:01:44, time: 0.364, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0021, loss_cls: 0.0182, acc: 99.3359, loss_bbox: 0.0304, loss: 0.0512
# 2021-09-02 14:59:12,990 - mmdet - INFO - Epoch [11][70/175]	lr: 2.500e-04, eta: 0:01:41, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0026, loss_cls: 0.0204, acc: 99.3652, loss_bbox: 0.0402, loss: 0.0635
# 2021-09-02 14:59:16,625 - mmdet - INFO - Epoch [11][80/175]	lr: 2.500e-04, eta: 0:01:37, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0027, loss_cls: 0.0224, acc: 99.3262, loss_bbox: 0.0419, loss: 0.0672
# 2021-09-02 14:59:20,262 - mmdet - INFO - Epoch [11][90/175]	lr: 2.500e-04, eta: 0:01:34, time: 0.364, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0026, loss_cls: 0.0216, acc: 99.2188, loss_bbox: 0.0398, loss: 0.0644
# 2021-09-02 14:59:23,892 - mmdet - INFO - Epoch [11][100/175]	lr: 2.500e-04, eta: 0:01:30, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0027, loss_cls: 0.0211, acc: 99.3359, loss_bbox: 0.0413, loss: 0.0654
# 2021-09-02 14:59:27,522 - mmdet - INFO - Epoch [11][110/175]	lr: 2.500e-04, eta: 0:01:26, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0028, loss_cls: 0.0210, acc: 99.3652, loss_bbox: 0.0428, loss: 0.0668
# 2021-09-02 14:59:31,152 - mmdet - INFO - Epoch [11][120/175]	lr: 2.500e-04, eta: 0:01:23, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0028, loss_cls: 0.0246, acc: 99.2480, loss_bbox: 0.0435, loss: 0.0712
# 2021-09-02 14:59:34,784 - mmdet - INFO - Epoch [11][130/175]	lr: 2.500e-04, eta: 0:01:19, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0029, loss_cls: 0.0224, acc: 99.3262, loss_bbox: 0.0464, loss: 0.0722
# 2021-09-02 14:59:38,442 - mmdet - INFO - Epoch [11][140/175]	lr: 2.500e-04, eta: 0:01:15, time: 0.366, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0029, loss_cls: 0.0236, acc: 99.3652, loss_bbox: 0.0528, loss: 0.0797
# 2021-09-02 14:59:42,073 - mmdet - INFO - Epoch [11][150/175]	lr: 2.500e-04, eta: 0:01:12, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0029, loss_cls: 0.0230, acc: 99.2969, loss_bbox: 0.0476, loss: 0.0739
# 2021-09-02 14:59:45,700 - mmdet - INFO - Epoch [11][160/175]	lr: 2.500e-04, eta: 0:01:08, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0028, loss_cls: 0.0211, acc: 99.3457, loss_bbox: 0.0402, loss: 0.0644
# 2021-09-02 14:59:49,330 - mmdet - INFO - Epoch [11][170/175]	lr: 2.500e-04, eta: 0:01:05, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0009, loss_rpn_bbox: 0.0026, loss_cls: 0.0203, acc: 99.3750, loss_bbox: 0.0406, loss: 0.0644
# 2021-09-02 14:59:56,930 - mmdet - INFO - Epoch [12][10/175]	lr: 2.500e-05, eta: 0:00:59, time: 0.574, data_time: 0.218, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0022, loss_cls: 0.0210, acc: 99.3750, loss_bbox: 0.0393, loss: 0.0628
# 2021-09-02 15:00:00,553 - mmdet - INFO - Epoch [12][20/175]	lr: 2.500e-05, eta: 0:00:56, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0031, loss_cls: 0.0223, acc: 99.3359, loss_bbox: 0.0462, loss: 0.0722
# 2021-09-02 15:00:04,170 - mmdet - INFO - Epoch [12][30/175]	lr: 2.500e-05, eta: 0:00:52, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0018, loss_cls: 0.0138, acc: 99.5996, loss_bbox: 0.0292, loss: 0.0452
# 2021-09-02 15:00:07,794 - mmdet - INFO - Epoch [12][40/175]	lr: 2.500e-05, eta: 0:00:48, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0024, loss_cls: 0.0178, acc: 99.4824, loss_bbox: 0.0325, loss: 0.0533
# 2021-09-02 15:00:11,433 - mmdet - INFO - Epoch [12][50/175]	lr: 2.500e-05, eta: 0:00:45, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0031, loss_cls: 0.0230, acc: 99.2773, loss_bbox: 0.0482, loss: 0.0746
# 2021-09-02 15:00:15,063 - mmdet - INFO - Epoch [12][60/175]	lr: 2.500e-05, eta: 0:00:41, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0028, loss_cls: 0.0225, acc: 99.2773, loss_bbox: 0.0410, loss: 0.0667
# 2021-09-02 15:00:18,706 - mmdet - INFO - Epoch [12][70/175]	lr: 2.500e-05, eta: 0:00:37, time: 0.364, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0012, loss_rpn_bbox: 0.0032, loss_cls: 0.0259, acc: 99.3164, loss_bbox: 0.0550, loss: 0.0853
# 2021-09-02 15:00:22,345 - mmdet - INFO - Epoch [12][80/175]	lr: 2.500e-05, eta: 0:00:34, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0030, loss_cls: 0.0263, acc: 99.1309, loss_bbox: 0.0514, loss: 0.0811
# 2021-09-02 15:00:25,974 - mmdet - INFO - Epoch [12][90/175]	lr: 2.500e-05, eta: 0:00:30, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0030, loss_cls: 0.0210, acc: 99.2871, loss_bbox: 0.0458, loss: 0.0703
# 2021-09-02 15:00:29,599 - mmdet - INFO - Epoch [12][100/175]	lr: 2.500e-05, eta: 0:00:27, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0023, loss_cls: 0.0205, acc: 99.4629, loss_bbox: 0.0370, loss: 0.0602
# 2021-09-02 15:00:33,227 - mmdet - INFO - Epoch [12][110/175]	lr: 2.500e-05, eta: 0:00:23, time: 0.363, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0024, loss_cls: 0.0183, acc: 99.5410, loss_bbox: 0.0360, loss: 0.0571
# 2021-09-02 15:00:36,862 - mmdet - INFO - Epoch [12][120/175]	lr: 2.500e-05, eta: 0:00:19, time: 0.363, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0028, loss_cls: 0.0187, acc: 99.4043, loss_bbox: 0.0367, loss: 0.0586
# 2021-09-02 15:00:40,513 - mmdet - INFO - Epoch [12][130/175]	lr: 2.500e-05, eta: 0:00:16, time: 0.365, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0029, loss_cls: 0.0224, acc: 99.4043, loss_bbox: 0.0447, loss: 0.0705
# 2021-09-02 15:00:44,160 - mmdet - INFO - Epoch [12][140/175]	lr: 2.500e-05, eta: 0:00:12, time: 0.365, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0032, loss_cls: 0.0239, acc: 99.3262, loss_bbox: 0.0493, loss: 0.0768
# 2021-09-02 15:00:47,794 - mmdet - INFO - Epoch [12][150/175]	lr: 2.500e-05, eta: 0:00:09, time: 0.364, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0027, loss_cls: 0.0213, acc: 99.3652, loss_bbox: 0.0407, loss: 0.0652
# 2021-09-02 15:00:51,416 - mmdet - INFO - Epoch [12][160/175]	lr: 2.500e-05, eta: 0:00:05, time: 0.362, data_time: 0.014, memory: 2231, loss_rpn_cls: 0.0001, loss_rpn_bbox: 0.0020, loss_cls: 0.0192, acc: 99.3945, loss_bbox: 0.0346, loss: 0.0559
# 2021-09-02 15:00:55,031 - mmdet - INFO - Epoch [12][170/175]	lr: 2.500e-05, eta: 0:00:01, time: 0.362, data_time: 0.015, memory: 2231, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0017, loss_cls: 0.0176, acc: 99.4727, loss_bbox: 0.0301, loss: 0.0496
# 2021-09-02 15:00:56,786 - mmdet - INFO - Saving checkpoint at 12 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 150/150, 11.8 task/s, elapsed: 13s, ETA:     0s
# ---------------iou_thr: 0.5---------------
# 2021-09-02 15:01:10,445 - mmdet - INFO -
# +------------+-----+------+--------+-------+
# | class      | gts | dets | recall | ap    |
# +------------+-----+------+--------+-------+
# | Car        | 455 | 641  | 0.886  | 0.764 |
# | Truck      | 22  | 47   | 1.000  | 1.000 |
# | Pedestrian | 71  | 156  | 0.592  | 0.495 |
# | Cyclist    | 66  | 97   | 0.212  | 0.037 |
# +------------+-----+------+--------+-------+
# | mAP        |     |      |        | 0.574 |
# +------------+-----+------+--------+-------+
# 2021-09-02 15:01:10,448 - mmdet - INFO - Epoch(val) [12][150]	AP50: 0.5740, mAP: 0.5740

# %% [markdown]
# ### 학습된 model을 이용하여 inference 수행

# %%
from mmdet.apis import inference_detector, init_detector, show_result_pyplot

# BGR Image 사용
Img = cv2.imread('/content/kitti_tiny/training/image_2/000068.jpeg')

model.cfg = cfg

result = inference_detector(model, img)
show_result_pyplot(model, img, result)
# Out:
# /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg/mmdet/datasets/utils.py:69: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   'data pipeline in your config file.', UserWarning)
# /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg/mmdet/core/anchor/anchor_generator.py:361: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '

# %% [markdown]
# ### 학습된 model을 이용하여 Video Detection 수행하기

# %%
# %cd /content
# !mkdir /content/data
# !wget -O /content/data/the_rock_chase.mp4 https://github.com/chulminkw/DLCV/blob/master/data/video/the_rock_chase.mp4?raw=true
# Out:
# /content
# --2021-09-02 15:01:29--  https://github.com/chulminkw/DLCV/blob/master/data/video/the_rock_chase.mp4?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/chulminkw/DLCV/raw/master/data/video/the_rock_chase.mp4 [following]
# --2021-09-02 15:01:30--  https://github.com/chulminkw/DLCV/raw/master/data/video/the_rock_chase.mp4
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/chulminkw/DLCV/master/data/video/the_rock_chase.mp4 [following]
# --2021-09-02 15:01:30--  https://raw.githubusercontent.com/chulminkw/DLCV/master/data/video/the_rock_chase.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10382594 (9.9M) [application/octet-stream]
# Saving to: ‘/content/data/the_rock_chase.mp4’
#
# /content/data/the_r 100%[===================>]   9.90M  --.-KB/s    in 0.06s
#
# 2021-09-02 15:01:31 (153 MB/s) - ‘/content/data/the_rock_chase.mp4’ saved [10382594/10382594]

# %%
CLASSES = ('Car', 'Truck', 'Pedestrian', 'Cyclist')
labels_to_names_seq = {i:k for i, k in enumerate(CLASSES)}
labels_to_names_seq
# Out:
# {0: 'Car', 1: 'Truck', 2: 'Pedestrian', 3: 'Cyclist'}

# %%
CLASSES = ('Car', 'Truck', 'Pedestrian', 'Cyclist')
cat2label = {k:i for i, k in enumerate(CLASSES)}

def get_detected_img(model, img_array, score_threshold=0.3, is_print=True):
    # 인자로 들어온 image_array를 복사. 
    draw_img =img_array.copy()
    bbox_color = (0, 255, 0)
    text_color = (0, 0, 255)

    # model과 image array를 입력 인자로 inference detection 수행하고 결과를 results로 받음. 
    # results는 80개의 2차원 array(shape=(오브젝트갯수, 5))를 가지는 list. 
    results = inference_detector(model, img_array)

    # 80개의 array원소를 가지는 results 리스트를 loop를 돌면서 개별 2차원 array들을 추출하고 이를 기반으로 이미지 시각화 
    # results 리스트의 위치 index가 바로 COCO 매핑된 Class id. 여기서는 result_ind가 class id
    # 개별 2차원 array에 오브젝트별 좌표와 class confidence score 값을 가짐. 
    for result_ind, result in enumerate(results):
        # 개별 2차원 array의 row size가 0 이면 해당 Class id로 값이 없으므로 다음 loop로 진행.
        if len(result) == 0:
            continue

        # 2차원 array에서 5번째 컬럼에 해당하는 값이 score threshold이며 이 값이 함수 인자로 들어온 score_threshold 보다 낮은 경우는 제외. 
        result_filtered = result[np.where(result[:, 4] > score_threshold)]

        # 해당 클래스 별로 Detect된 여러개의 오브젝트 정보가 2차원 array에 담겨 있으며, 이 2차원 array를 row수만큼 iteration해서 개별 오브젝트의 좌표값 추출. 
        for i in range(len(result_filtered)):
            # 좌상단, 우하단 좌표 추출. 
            left = int(result_filtered[i, 0])
            top = int(result_filtered[i, 1])
            right = int(result_filtered[i, 2])
            bottom = int(result_filtered[i, 3])
            caption = '{}: {:.4f}'.format(labels_to_names_seq[result_ind], result_filtered[i, 4])
            cv2.rectangle(draw_img, (left, top), (right, bottom), color=bbox_color, thickness=2)
            cv2.putText(draw_img, caption, (int(left), int(top+7)), cv2.FONT_HERSHEY_COMPLEX, 0.37, text_color, 1)
            if is_print:
                print(caption)

    return draw_img

# %%
import time

def do_detected_video(model, input_path, output_path, score_threshold, do_print=True):

    cap = cv2.VideoCapture(input_path)

    codec = cv2.VideoWriter_fourcc(*'XVID')

    vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    vid_fps = cap.get(cv2.CAP_PROP_FPS)

    vid_writer = cv2.VideoWriter(output_path, codec, vid_fps, vid_size)

    frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print('총 frame 개수:', frame_cnt)
    btime = time.time()
    while True:
        hasFrame, img_frame = cap.read()
        if not hasFrame:
            print('더 이상 처리할 frame이 없습니다.')
            break

        stime = time.time()
        img_frame = get_detected_img(model, img_frame, score_threshold=score_threshold, is_print=False)

        if do_print:
            print('frame별 detection 수행 시간:', round(time.time() - stime, 4))
        vid_writer.write(img_frame)

    vid_writer.release()
    cap.release()

    print('최종 detection 완료 수행 시간:', round(time.time() - btime, 4))

# %%
do_detected_video(model, '/content/data/the_rock_chase.mp4', '/content/data/the_rock_chase_out1.mp4', score_threshold=0.4, do_print=True)
# Out:
# 총 frame 개수: 503
# frame별 detection 수행 시간: 0.1706
# /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /usr/local/lib/python3.7/dist-packages/mmdet-2.16.0-py3.7.egg/mmdet/core/anchor/anchor_generator.py:361: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '
# frame별 detection 수행 시간: 0.1533
# frame별 detection 수행 시간: 0.1129
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1075
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.1074
# frame별 detection 수행 시간: 0.1114
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.1084
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1085
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.1085
# frame별 detection 수행 시간: 0.1107
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.1076
# frame별 detection 수행 시간: 0.108
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.1085
# frame별 detection 수행 시간: 0.1088
# frame별 detection 수행 시간: 0.1119
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1081
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1107
# frame별 detection 수행 시간: 0.108
# frame별 detection 수행 시간: 0.1082
# frame별 detection 수행 시간: 0.1079
# frame별 detection 수행 시간: 0.1082
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1068
# frame별 detection 수행 시간: 0.1082
# frame별 detection 수행 시간: 0.1081
# frame별 detection 수행 시간: 0.1082
# frame별 detection 수행 시간: 0.1087
# frame별 detection 수행 시간: 0.1077
# frame별 detection 수행 시간: 0.1122
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.107
# frame별 detection 수행 시간: 0.1106
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.108
# frame별 detection 수행 시간: 0.1074
# frame별 detection 수행 시간: 0.1081
# frame별 detection 수행 시간: 0.1078
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.1077
# frame별 detection 수행 시간: 0.1078
# frame별 detection 수행 시간: 0.1074
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1084
# frame별 detection 수행 시간: 0.1085
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1081
# frame별 detection 수행 시간: 0.1068
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.1078
# frame별 detection 수행 시간: 0.108
# frame별 detection 수행 시간: 0.1079
# frame별 detection 수행 시간: 0.108
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.1076
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.1088
# frame별 detection 수행 시간: 0.1076
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1073
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1095
# frame별 detection 수행 시간: 0.1076
# frame별 detection 수행 시간: 0.1113
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1075
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1088
# frame별 detection 수행 시간: 0.1082
# frame별 detection 수행 시간: 0.1104
# frame별 detection 수행 시간: 0.108
# frame별 detection 수행 시간: 0.1077
# frame별 detection 수행 시간: 0.108
# frame별 detection 수행 시간: 0.1106
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1095
# frame별 detection 수행 시간: 0.1082
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.1085
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1112
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1101
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.1107
# frame별 detection 수행 시간: 0.1095
# frame별 detection 수행 시간: 0.1116
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1117
# frame별 detection 수행 시간: 0.1113
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.1084
# frame별 detection 수행 시간: 0.108
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1087
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1076
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.1088
# frame별 detection 수행 시간: 0.1101
# frame별 detection 수행 시간: 0.1095
# frame별 detection 수행 시간: 0.1085
# frame별 detection 수행 시간: 0.1084
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1081
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1085
# frame별 detection 수행 시간: 0.1068
# frame별 detection 수행 시간: 0.1084
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.1077
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.112
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1073
# frame별 detection 수행 시간: 0.1078
# frame별 detection 수행 시간: 0.1076
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.1088
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.1078
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1082
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1075
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1079
# frame별 detection 수행 시간: 0.1101
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1075
# frame별 detection 수행 시간: 0.1109
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.1078
# frame별 detection 수행 시간: 0.1109
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1072
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.111
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1104
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.108
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1078
# frame별 detection 수행 시간: 0.1084
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1107
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.108
# frame별 detection 수행 시간: 0.111
# frame별 detection 수행 시간: 0.1079
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1079
# frame별 detection 수행 시간: 0.1084
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1087
# frame별 detection 수행 시간: 0.1087
# frame별 detection 수행 시간: 0.1127
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1079
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1101
# frame별 detection 수행 시간: 0.1082
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1076
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1106
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.1121
# frame별 detection 수행 시간: 0.1087
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1095
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1088
# frame별 detection 수행 시간: 0.1076
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1107
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1061
# frame별 detection 수행 시간: 0.1085
# frame별 detection 수행 시간: 0.1076
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1081
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1109
# frame별 detection 수행 시간: 0.1079
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1077
# frame별 detection 수행 시간: 0.1101
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1118
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.107
# frame별 detection 수행 시간: 0.1091
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1104
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.112
# frame별 detection 수행 시간: 0.1107
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1107
# frame별 detection 수행 시간: 0.1115
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1106
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1129
# frame별 detection 수행 시간: 0.1126
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1109
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1118
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1115
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.1114
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1113
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.1082
# frame별 detection 수행 시간: 0.1117
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.1084
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.1109
# frame별 detection 수행 시간: 0.1081
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.112
# frame별 detection 수행 시간: 0.1083
# frame별 detection 수행 시간: 0.1138
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.1115
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1122
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1127
# frame별 detection 수행 시간: 0.111
# frame별 detection 수행 시간: 0.1104
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.112
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1117
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1104
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1086
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1118
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1121
# frame별 detection 수행 시간: 0.1114
# frame별 detection 수행 시간: 0.1095
# frame별 detection 수행 시간: 0.1095
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.111
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1126
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1117
# frame별 detection 수행 시간: 0.1088
# frame별 detection 수행 시간: 0.1126
# frame별 detection 수행 시간: 0.1095
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1077
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.1106
# frame별 detection 수행 시간: 0.1113
# frame별 detection 수행 시간: 0.1101
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1112
# frame별 detection 수행 시간: 0.1113
# frame별 detection 수행 시간: 0.112
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1106
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1088
# frame별 detection 수행 시간: 0.1088
# frame별 detection 수행 시간: 0.1104
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1101
# frame별 detection 수행 시간: 0.1082
# frame별 detection 수행 시간: 0.1106
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.111
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1126
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.1101
# frame별 detection 수행 시간: 0.1118
# frame별 detection 수행 시간: 0.1092
# frame별 detection 수행 시간: 0.1075
# frame별 detection 수행 시간: 0.1077
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1089
# frame별 detection 수행 시간: 0.1096
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1097
# frame별 detection 수행 시간: 0.1095
# frame별 detection 수행 시간: 0.109
# frame별 detection 수행 시간: 0.1126
# frame별 detection 수행 시간: 0.1075
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.1104
# frame별 detection 수행 시간: 0.1099
# frame별 detection 수행 시간: 0.1134
# frame별 detection 수행 시간: 0.1124
# frame별 detection 수행 시간: 0.1116
# frame별 detection 수행 시간: 0.1104
# frame별 detection 수행 시간: 0.1124
# frame별 detection 수행 시간: 0.1119
# frame별 detection 수행 시간: 0.1122
# frame별 detection 수행 시간: 0.113
# frame별 detection 수행 시간: 0.1107
# frame별 detection 수행 시간: 0.1125
# frame별 detection 수행 시간: 0.114
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1123
# frame별 detection 수행 시간: 0.1114
# frame별 detection 수행 시간: 0.1114
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1106
# frame별 detection 수행 시간: 0.1113
# frame별 detection 수행 시간: 0.1127
# frame별 detection 수행 시간: 0.1124
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1109
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.1114
# frame별 detection 수행 시간: 0.1119
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.1095
# frame별 detection 수행 시간: 0.1109
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1106
# frame별 detection 수행 시간: 0.1085
# frame별 detection 수행 시간: 0.11
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1122
# frame별 detection 수행 시간: 0.1106
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1107
# frame별 detection 수행 시간: 0.1121
# frame별 detection 수행 시간: 0.112
# frame별 detection 수행 시간: 0.1121
# frame별 detection 수행 시간: 0.1137
# frame별 detection 수행 시간: 0.1102
# frame별 detection 수행 시간: 0.1116
# frame별 detection 수행 시간: 0.1132
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.1128
# frame별 detection 수행 시간: 0.1123
# frame별 detection 수행 시간: 0.1116
# frame별 detection 수행 시간: 0.1138
# frame별 detection 수행 시간: 0.1103
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1123
# frame별 detection 수행 시간: 0.1133
# frame별 detection 수행 시간: 0.1129
# frame별 detection 수행 시간: 0.1094
# frame별 detection 수행 시간: 0.1108
# frame별 detection 수행 시간: 0.112
# frame별 detection 수행 시간: 0.1121
# frame별 detection 수행 시간: 0.1105
# frame별 detection 수행 시간: 0.1093
# frame별 detection 수행 시간: 0.1077
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.1109
# frame별 detection 수행 시간: 0.112
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.1114
# frame별 detection 수행 시간: 0.1129
# frame별 detection 수행 시간: 0.1127
# frame별 detection 수행 시간: 0.1114
# frame별 detection 수행 시간: 0.1157
# frame별 detection 수행 시간: 0.1121
# frame별 detection 수행 시간: 0.115
# frame별 detection 수행 시간: 0.1135
# frame별 detection 수행 시간: 0.113
# frame별 detection 수행 시간: 0.111
# frame별 detection 수행 시간: 0.1098
# frame별 detection 수행 시간: 0.1122
# frame별 detection 수행 시간: 0.1123
# frame별 detection 수행 시간: 0.1101
# frame별 detection 수행 시간: 0.1111
# frame별 detection 수행 시간: 0.1142
# 더 이상 처리할 frame이 없습니다.
# 최종 detection 완료 수행 시간: 59.3993
