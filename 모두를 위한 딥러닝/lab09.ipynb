# %% [markdown]
# # lab09 - Neural Net for XOR, Tensorboard

# %%
import numpy as np
import tensorflow as tf
import datetime
import os

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## XOR

# %%
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2, activation='sigmoid'))
tf.model.compile(loss='binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.01), metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_data, y_data, epochs=1000)

predictions = tf.model.predict(x_data)
print("Prediction: \n", predictions)

score = tf.model.evaluate(x_data, y_data)
print("Accuracy: \n", score[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7993 - accuracy: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7987 - accuracy: 0.2500
# Epoch 3/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7981 - accuracy: 0.2500
# Epoch 4/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7975 - accuracy: 0.2500
# Epoch 5/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7969 - accuracy: 0.2500
# Epoch 6/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7963 - accuracy: 0.2500
# Epoch 7/1000
# ...

# %% [markdown]
# ## XOR using NN
#
# ![image-2.png](attachment:image-2.png)

# %%
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2, activation='sigmoid'))
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2, activation='sigmoid'))
tf.model.compile(loss='binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.1), metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_data, y_data, epochs=10000)

predictions = tf.model.predict(x_data)
print("Prediction: \n", predictions)

score = tf.model.evaluate(x_data, y_data)
print("Accuracy: ", score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 1)                 3
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 2
# ...
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6945 - accuracy: 0.5000
# Epoch 2/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6944 - accuracy: 0.5000
# Epoch 3/10000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6944 - accuracy: 0.5000
# Epoch 4/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6943 - accuracy: 0.5000
# Epoch 5/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6942 - accuracy: 0.5000
# ...

# %% [markdown]
# ## XOR using NN Deep and Wide

# %%
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=10, input_dim=2, activation='sigmoid'))
tf.model.add(tf.keras.layers.Dense(units=10, activation='sigmoid'))
tf.model.add(tf.keras.layers.Dense(units=10, activation='sigmoid'))
tf.model.add(tf.keras.layers.Dense(units=10, activation='sigmoid'))
tf.model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# SGD not working very well due to vanishing gradient problem, switched to Adem for now
# or you may use activation='relu'
tf.model.compile(loss='binary_crossentropy', optimizer=tf.optimizers.Adam(lr=0.1), metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_data, y_data, epochs=5000)

predictions = tf.model.predict(x_data)
print('Predictions: \n', predictions)

score = tf.model.evaluate(x_data, y_data)
print('Accuracy: ', score[1])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 11
# ...
# Total params: 371
# Trainable params: 371
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7543 - accuracy: 0.5000
# Epoch 2/5000
# ...

# %% [markdown]
# ## MNIST
#
# ### activation='softmax', units=10, optimizer='SGD'

# %%
mnist = tf.keras.datasets.mnist
print("mnist download complete")
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print('x_train shape: ', x_train.shape)
print('y_train shape: ', y_train.shape)

x_train, x_test = x_train / 255.0, x_test / 255.0
print("normalization done")

model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='SGD', metrics=['accuracy'])

model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# mnist download complete
# x_train shape:  (60000, 28, 28)
# y_train shape:  (60000,)
# normalization done
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_3 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_29 (Dense)             (None, 10)                110
# ...
# Total params: 8,290
# ...

# %% [markdown]
# ### activation='softmax', units=784, optimizer='SGD'

# %%
model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=784, activation='softmax'))
model.add(tf.keras.layers.Dense(units=784, activation='softmax'))
model.add(tf.keras.layers.Dense(units=784, activation='softmax'))
model.add(tf.keras.layers.Dense(units=784, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='SGD', metrics=['accuracy'])
model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_4 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_31 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_32 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_33 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_34 (Dense)             (None, 10)                7850
# ...
# Total params: 2,469,610
# Trainable params: 2,469,610
# Non-trainable params: 0
# ...

# %% [markdown]
# ### activation='softmax', units=10, optimizer='Adam'

# %%
model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_5 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_38 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_39 (Dense)             (None, 10)                110
# ...
# Total params: 8,290
# Trainable params: 8,290
# Non-trainable params: 0
# ...

# %% [markdown]
# ### activation='softmax', units=10, optimizer=tf.optimizersAdam(lr=0.1)

# %%
model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.optimizers.Adam(lr=0.1), metrics=['accuracy'])

model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_7 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dense_46 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_47 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_48 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_49 (Dense)             (None, 10)                110
# ...
# Total params: 8,290
# Trainable params: 8,290
# Non-trainable params: 0
# ...

# %% [markdown]
# ### activations='softmax', units=10, optimizer=tf.optimizers.Adam(lr=0.001)

# %%
model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.optimizers.Adam(lr=0.001), metrics=['accuracy'])

model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_8 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_50 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dense_51 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_52 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_53 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_54 (Dense)             (None, 10)                110
# ...
# Total params: 8,290
# Trainable params: 8,290
# Non-trainable params: 0
# ...

# %% [markdown]
# ### activation='softmax', units=784, optimizer='Adam'

# %%
model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=784, activation='softmax'))
model.add(tf.keras.layers.Dense(units=784, activation='softmax'))
model.add(tf.keras.layers.Dense(units=784, activation='softmax'))
model.add(tf.keras.layers.Dense(units=784, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_6 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_41 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_42 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_43 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_44 (Dense)             (None, 10)                7850
# ...
# Total params: 2,469,610
# Trainable params: 2,469,610
# Non-trainable params: 0
# ...

# %% [markdown]
# ### activation='softmax', units=10, optimizer=tf.optimizers.Adam(lr=0.0001)

# %%
model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.optimizers.Adam(lr=0.0001), metrics=['accuracy'])
model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_10 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dense_61 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_62 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_63 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_64 (Dense)             (None, 10)                110
# ...
# Total params: 8,290
# Trainable params: 8,290
# Non-trainable params: 0
# ...

# %% [markdown]
# ### activation='softmax', units=100, optimizer=tf.optimizers.Adam(lr=0.001)

# %%
model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=100, activation='softmax'))
model.add(tf.keras.layers.Dense(units=100, activation='softmax'))
model.add(tf.keras.layers.Dense(units=100, activation='softmax'))
model.add(tf.keras.layers.Dense(units=100, activation='softmax'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.optimizers.Adam(lr=0.001), metrics=['accuracy'])
model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_11 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 100)               78500
# _________________________________________________________________
# dense_66 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_67 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_68 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_69 (Dense)             (None, 10)                1010
# ...
# Total params: 109,810
# Trainable params: 109,810
# Non-trainable params: 0
# ...

# %% [markdown]
# ### activation='sigmoid', units=10, optimizer=tf.optimizers.Adam(lr=0.001)

# %%
model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=10, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=10, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=10, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=10, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=10, activation='sigmoid'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.optimizers.Adam(lr=0.001), metrics=['accuracy'])
model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_12 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_70 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dense_71 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_72 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_73 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_74 (Dense)             (None, 10)                110
# ...
# Total params: 8,290
# Trainable params: 8,290
# Non-trainable params: 0
# ...

# %% [markdown]
# ### activation='sigmoid', units=100, oprimizer=tf.optimizers.Adam(lr=0.001)

# %%
model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=100, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=100, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=100, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=100, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=10, activation='sigmoid'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.optimizers.Adam(lr=0.001), metrics=['accuracy'])
model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_13 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_75 (Dense)             (None, 100)               78500
# _________________________________________________________________
# dense_76 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_77 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_78 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_79 (Dense)             (None, 10)                1010
# ...
# Total params: 109,810
# Trainable params: 109,810
# Non-trainable params: 0
# ...

# %% [markdown]
# ### activation='sigmoid', units=784, optimizer=tf.optimizers.Adam(lr=0.001)

# %%
model = tf.keras.models.Sequential()
# image 28x28 pixel
model.add(tf.keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(tf.keras.layers.Dense(units=784, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=784, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=784, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=784, activation='sigmoid'))
model.add(tf.keras.layers.Dense(units=10, activation='sigmoid'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.optimizers.Adam(lr=0.001), metrics=['accuracy'])
model.summary()

model.fit(x_train, y_train, epochs=5)

# Calculate the accuracy
print(model.evaluate(x_test, y_test, return_dict=True))
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_14 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_80 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_81 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_82 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_83 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dense_84 (Dense)             (None, 10)                7850
# ...
# Total params: 2,469,610
# Trainable params: 2,469,610
# Non-trainable params: 0
# ...

# %% [markdown]
# ## Tensorboard

# %%
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=2, input_dim=2, activation='sigmoid'))
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2, activation='sigmoid'))
tf.model.compile(loss='binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.1), metrics=['accuracy'])
tf.model.summary()

# prepare callback
log_dir = os.path.join(".", "logs", "fit", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# add callback param to fit()
history = tf.model.fit(x_data, y_data, epochs=10000, callbacks=[tensorboard_callback])

predictions = tf.model.predict(x_data)
print("Predictions: \n", predictions)

score = tf.model.evaluate(x_data, y_data)
print("accuracy: ", score[1])

'''
at the end of the run, open terminal / command window
cd to the source directory
tensorboard --logdir logs/fit
'''
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_85 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_86 (Dense)             (None, 1)                 3
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7263 - accuracy: 0.5000
# Epoch 2/10000
# WARNING:tensorflow:From C:\Users\tjswn\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7238 - accuracy: 0.5000
# ...
